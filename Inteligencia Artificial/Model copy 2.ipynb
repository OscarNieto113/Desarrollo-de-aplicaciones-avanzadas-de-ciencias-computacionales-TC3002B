# %%
import os
import shutil
import numpy as np
import pickle
import keras
from sklearn.metrics import precision_score, recall_score, f1_score
import logging
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential, load_model
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import os

classes = {}

def create_directories(base_dir, categories):
    """
    Create directories for training, testing, and validation datasets.

    Parameters:
    - base_dir (str): The base directory where the train, test, and validation directories will be created.
    - categories (list): List of category names (sub-directory names) to create inside each of train, test, and validation directories.
    """
    for subset in ['train', 'test', 'validation']:
        for category in categories:
            dir_path = os.path.join(base_dir, subset, category)
            os.makedirs(dir_path, exist_ok=True)
            logging.info(f'Created directory: {dir_path}')

def copy_images(source_dir, images, dest_dir):
    """
    Copy images from source directory to destination directory.

    Parameters:
    - source_dir (str): The directory containing the source images.
    - images (list): List of image filenames to copy.
    - dest_dir (str): The destination directory where images will be copied.
    """
    for image in images:
        shutil.copy(os.path.join(source_dir, image), os.path.join(dest_dir, image))
        logging.info(f'Copied {image} to {dest_dir}')

def split_dataset(source_dir, base_dir, split_ratios=(0.7, 0.15, 0.15)):
    """
    Split the dataset into training, testing, and validation sets.

    Parameters:
    - source_dir (str): The source directory containing subdirectories of images for each category.
    - base_dir (str): The base directory where the split datasets will be stored.
    - split_ratios (tuple): A tuple containing the ratios for splitting the dataset into train, test, and validation sets.

    Raises:
    - ValueError: If the split ratios do not sum to 1.
    """
    if sum(split_ratios) != 1:
        raise ValueError("Split ratios must sum to 1. Provided ratios sum to {:.2f}".format(sum(split_ratios)))
    
    categories = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
    create_directories(base_dir, categories)

    for category in categories:
        category_path = os.path.join(source_dir, category)
        images = os.listdir(category_path)
        np.random.shuffle(images)

        train_split = int(len(images) * split_ratios[0])
        test_split = int(len(images) * split_ratios[1])

        train_images = images[:train_split]
        test_images = images[train_split:train_split + test_split]
        validation_images = images[train_split + test_split:]

        copy_images(category_path, train_images, os.path.join(base_dir, 'train', category))
        copy_images(category_path, test_images, os.path.join(base_dir, 'test', category))
        copy_images(category_path, validation_images, os.path.join(base_dir, 'validation', category))
        
def preprocess_image(image_path):
    img = Image.open(image_path)
    if img.mode == 'P' and 'transparency' in img.info:
        img = img.convert('RGBA')
        img = img.convert('RGB')
    if img.mode == 'RGBA':
        img = img.convert('RGB')
    return img

def setup_and_split_dataset(source_dir='Data', base_dir='Dataset_Split', split_ratios=(0.7, 0.15, 0.15)):
    """
    Set up logging, define directories, and split the dataset.

    Parameters:
    - source_dir (str): The source directory containing subdirectories of images for each category.
    - base_dir (str): The base directory where the split datasets will be stored.
    - split_ratios (tuple): A tuple containing the ratios for splitting the dataset into train, test, and validation sets.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    try:
        split_dataset(source_dir, base_dir, split_ratios)
    except ValueError as e:
        logging.error(e)
        
def load_dataset(base_dir, target_size=(150, 150), batch_size=32, augmentation=False):
    """
    Load the dataset into variables using ImageDataGenerator.

    Parameters:
    - base_dir (str): The base directory where the split datasets are stored.
    - target_size (tuple): The dimensions to which all images found will be resized.
    - batch_size (int): Size of the batches of data (default: 32).
    - augmentation (bool): Whether to apply data augmentation to the training dataset (default: False).

    Returns:
    - train_generator (DirectoryIterator): Iterator for training dataset.
    - test_generator (DirectoryIterator): Iterator for testing dataset.
    - validation_generator (DirectoryIterator): Iterator for validation dataset.
    """
    if augmentation:
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=90,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True)
    else:
        train_datagen = ImageDataGenerator(rescale=1./255)

    test_datagen = ImageDataGenerator(rescale=1./255)
    validation_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(
        os.path.join(base_dir, 'train'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    test_generator = test_datagen.flow_from_directory(
        os.path.join(base_dir, 'test'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    validation_generator = validation_datagen.flow_from_directory(
        os.path.join(base_dir, 'validation'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    return train_generator, test_generator, validation_generator

def display_images(images, labels, classes, num_images=9):
    num_images = min(num_images, len(images), len(labels))
    grid_size = int(np.ceil(np.sqrt(num_images)))
    plt.figure(figsize=(10, 10))
    
    for i in range(num_images):
        ax = plt.subplot(grid_size, grid_size, i + 1)
        image = images[i]

        if image.shape[-1] == 3:
            image = np.clip(image * 255, 0, 255).astype("uint8")

        plt.imshow(image)
        
        # Get the class name from the label
        class_name = classes[labels[i].argmax()] if labels[i].ndim > 0 else classes[labels[i]]
        plt.title(f"Label: {class_name}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    setup_and_split_dataset()
    
    base_dir = 'Dataset_Split'
    train_generator, test_generator, validation_generator = load_dataset(base_dir, augmentation=True)
    
    classes = {v: k for k, v in train_generator.class_indices.items()}

    images, labels = next(train_generator)
    display_images(images, labels, classes)
# Out:
# 2024-06-03 11:17:38,606 - INFO - Created directory: Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,608 - INFO - Created directory: Dataset_Split\train\Jinbei
# 2024-06-03 11:17:38,610 - INFO - Created directory: Dataset_Split\test\Chopper
# 2024-06-03 11:17:38,611 - INFO - Created directory: Dataset_Split\test\Jinbei
# 2024-06-03 11:17:38,613 - INFO - Created directory: Dataset_Split\validation\Chopper
# 2024-06-03 11:17:38,615 - INFO - Created directory: Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:38,621 - INFO - Copied 82.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,624 - INFO - Copied 110.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,627 - INFO - Copied 84.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,630 - INFO - Copied 54.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,637 - INFO - Copied 55.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,640 - INFO - Copied 17.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,643 - INFO - Copied 183.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,646 - INFO - Copied 83.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,650 - INFO - Copied 95.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,656 - INFO - Copied 5.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,661 - INFO - Copied modified_59.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,665 - INFO - Copied 11.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,669 - INFO - Copied 46.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,674 - INFO - Copied 155.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,677 - INFO - Copied 2.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,681 - INFO - Copied modified_124.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38,684 - INFO - Copied 58.png to Dataset_Split\train\Chopper
# 2024-06-03 11:17:38
png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,400 - INFO - Copied modified191 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,404 - INFO - Copied 187 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,407 - INFO - Copied 166 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,411 - INFO - Copied modified186 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,414 - INFO - Copied 182 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,418 - INFO - Copied 52.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,422 - INFO - Copied modified194 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,425 - INFO - Copied modified19.png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,428 - INFO - Copied 216.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,430 - INFO - Copied 196 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,433 - INFO - Copied modified61.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,437 - INFO - Copied 93.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,440 - INFO - Copied modified153.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,443 - INFO - Copied modified7.png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,446 - INFO - Copied 8.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,449 - INFO - Copied 144.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,452 - INFO - Copied 23.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,456 - INFO - Copied 168 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,459 - INFO - Copied 136.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,462 - INFO - Copied modified174 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,464 - INFO - Copied modified146.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,469 - INFO - Copied 106.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,471 - INFO - Copied 134.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,475 - INFO - Copied 167 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,478 - INFO - Copied modified95.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,481 - INFO - Copied 182 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,484 - INFO - Copied modified212.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,488 - INFO - Copied modified183 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,491 - INFO - Copied modified75.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,494 - INFO - Copied 151 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,498 - INFO - Copied 14.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,501 - INFO - Copied 95.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,505 - INFO - Copied 175 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,508 - INFO - Copied modified217.png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,510 - INFO - Copied modified92.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,513 - INFO - Copied 203.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,516 - INFO - Copied 197 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,521 - INFO - Copied modified156.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,525 - INFO - Copied 141.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,536 - INFO - Copied 39.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,540 - INFO - Copied modified200 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,543 - INFO - Copied 27.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,546 - INFO - Copied 201.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,549 - INFO - Copied 171 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,552 - INFO - Copied 195 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,558 - INFO - Copied 84.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,566 - INFO - Copied 53.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,571 - INFO - Copied 43.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,574 - INFO - Copied 109.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,579 - INFO - Copied 10.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,583 - INFO - Copied 114.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,587 - INFO - Copied modified53.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,592 - INFO - Copied 17.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,595 - INFO - Copied modified23.png.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,598 - INFO - Copied 174.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,601 - INFO - Copied modified213.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,605 - INFO - Copied 65.jpeg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,614 - INFO - Copied 111.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,617 - INFO - Copied 178 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,621 - INFO - Copied modified55.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,624 - INFO - Copied 156 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,626 - INFO - Copied 2.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,629 - INFO - Copied 181 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,632 - INFO - Copied 27.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,637 - INFO - Copied 156 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,640 - INFO - Copied 42.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,643 - INFO - Copied 98.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,646 - INFO - Copied 179 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,650 - INFO - Copied 174 .png to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,655 - INFO - Copied 153.jpg to Dataset_Split\validation\Jinbei
# 2024-06-03 11:17:43,658 - INFO - Copied modified185 .png.png to Dataset_Split\validation\Jinbei
# Found 908 images belonging to 2 classes.
# Found 194 images belonging to 2 classes.
# Found 197 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D((2, 2)),  # Capa de pooling

    # Capa convolucional con 128 filtros y función de activación ReLU
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),  # Capa de pooling

    # Capa convolucional con 256 filtros y función de activación ReLU
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),  # Capa de pooling

    # Capa convolucional con 512 filtros y función de activación ReLU
    Conv2D(512, (3, 3), activation='relu'),

    Flatten(),  # Aplanar la salida para conectarla a capas densas

    # Capa densa con 512 neuronas y función de activación ReLU
    Dense(512, activation='relu'),

    # Capa densa de salida con activación sigmoide para clasificación binaria
    Dense(len(train_generator.class_indices), activation='sigmoid')
])

# Compilar el modelo con el optimizador Adam y una tasa de aprendizaje reducida
opt = Adam(learning_rate=0.0005)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=opt)

# Muestra el resumen del modelo
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 148, 148, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 74, 74, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 72, 72, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 36, 36, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 34, 34, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 17, 17, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 15, 15, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │    58,982,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,534,914 (230.92 MB)
#  Trainable params: 60,534,914 (230.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_generator, epochs=50, validation_data=validation_generator)
# Out:
# Epoch 1/50
# c:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# c:\Python312\Lib\site-packages\PIL\Image.py:1000: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.4843 - loss: 1.2175 - val_accuracy: 0.5025 - val_loss: 0.6931
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 926ms/step - accuracy: 0.5136 - loss: 0.6928 - val_accuracy: 0.4975 - val_loss: 0.7014
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 959ms/step - accuracy: 0.5310 - loss: 0.6906 - val_accuracy: 0.5076 - val_loss: 0.6928
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 932ms/step - accuracy: 0.5587 - loss: 0.6827 - val_accuracy: 0.5990 - val_loss: 0.6572
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.6367 - loss: 0.6409 - val_accuracy: 0.6853 - val_loss: 0.5992
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 930ms/step - accuracy: 0.7236 - loss: 0.5578 - val_accuracy: 0.7563 - val_loss: 0.4656
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 934ms/step - accuracy: 0.7746 - loss: 0.4544 - val_accuracy: 0.7411 - val_loss: 0.5279
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 941ms/step - accuracy: 0.8121 - loss: 0.4387 - val_accuracy: 0.7970 - val_loss: 0.4138
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.8172 - loss: 0.4271 - val_accuracy: 0.8071 - val_loss: 0.4260
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 940ms/step - accuracy: 0.8424 - loss: 0.3755 - val_accuracy: 0.7411 - val_loss: 0.6302
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 978ms/step - accuracy: 0.8422 - loss: 0.3465 - val_accuracy: 0.8782 - val_loss: 0.2907
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 939ms/step - accuracy: 0.8775 - loss: 0.3273 - val_accuracy: 0.8528 - val_loss: 0.3057
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 938ms/step - accuracy: 0.8726 - loss: 0.3053 - val_accuracy: 0.8579 - val_loss: 0.3839
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 933ms/step - accuracy: 0.8848 - loss: 0.2820 - val_accuracy: 0.7665 - val_loss: 0.5120
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 943ms/step - accuracy: 0.8667 - loss: 0.3356 - val_accuracy: 0.8274 - val_loss: 0.3906
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 933ms/step - accuracy: 0.8616 - loss: 0.3137 - val_accuracy: 0.9137 - val_loss: 0.2376
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.8741 - loss: 0.2989 - val_accuracy: 0.9086 - val_loss: 0.2418
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s
50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 937ms/step - accuracy: 0.9366 - loss: 0.1483 - val_accuracy: 0.9239 - val_loss: 0.2575
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 950ms/step - accuracy: 0.9563 - loss: 0.1173 - val_accuracy: 0.9442 - val_loss: 0.1384
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 935ms/step - accuracy: 0.9677 - loss: 0.0848 - val_accuracy: 0.9391 - val_loss: 0.1381
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 934ms/step - accuracy: 0.9539 - loss: 0.1207 - val_accuracy: 0.9239 - val_loss: 0.1985
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 934ms/step - accuracy: 0.9399 - loss: 0.1614 - val_accuracy: 0.9188 - val_loss: 0.2335
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 954ms/step - accuracy: 0.9463 - loss: 0.1336 - val_accuracy: 0.9340 - val_loss: 0.1473
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 928ms/step - accuracy: 0.9459 - loss: 0.1238 - val_accuracy: 0.9137 - val_loss: 0.4027
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 28s 931ms/step - accuracy: 0.9300 - loss: 0.1570 - val_accuracy: 0.9086 - val_loss: 0.1683
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 927ms/step - accuracy: 0.9490 - loss: 0.1276 - val_accuracy: 0.9340 - val_loss: 0.1853

# %%
def plot_history(history):
    training_accuracy = history.history['accuracy']
    validation_accuracy = history.history['val_accuracy']
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].plot(training_accuracy, label='Training Accuracy', color='blue', linestyle='-', marker='o')
    axes[0].plot(validation_accuracy, label='Validation Accuracy', color='green', linestyle='-', marker='o')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()

    axes[1].plot(training_loss, label='Training Loss', color='blue', linestyle='-', marker='o')
    axes[1].plot(validation_loss, label='Validation Loss', color='green', linestyle='-', marker='o')
    axes[1].set_title('Training and Validation Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()

    plt.tight_layout()

    plt.show()

def save_history(history, filename):
    """Save the history object to a file."""
    with open(filename, 'wb') as file:
        pickle.dump(history.history, file)
    print(f"History object saved successfully in {filename}")
    
def load_history(filename):
    """Load the history object from a file."""
    with open(filename, 'rb') as file:
        history = pickle.load(file)
    print(f"History object loaded successfully from {filename}")
    return history

def plot_confusion_matrices(model, train_generator, validation_generator, classes):
    """Plot confusion matrices for training and validation data."""
    y_pred_train = model.predict(train_generator)
    y_pred_validation = model.predict(validation_generator)

    y_pred_train_classes = np.argmax(y_pred_train, axis=1)
    y_pred_validation_classes = np.argmax(y_pred_validation, axis=1)

    y_true_train = train_generator.classes
    y_true_validation = validation_generator.classes

    cm_train = confusion_matrix(y_true_train, y_pred_train_classes)
    cm_validation = confusion_matrix(y_true_validation, y_pred_validation_classes)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues', xticklabels=classes.values(), yticklabels=classes.values())
    plt.title('Confusion Matrix - Training Data')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    plt.subplot(1, 2, 2)
    sns.heatmap(cm_validation, annot=True, fmt='d', cmap='Blues', xticklabels=classes.values(), yticklabels=classes.values())
    plt.title('Confusion Matrix - Validation Data')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    plt.tight_layout()
    plt.show()

def calculate_and_print_metrics(model, validation_generator):
    """Calculate and print accuracy, precision, recall, and F1-score."""
    y_pred_validation = model.predict(validation_generator)
    y_pred_validation_classes = np.argmax(y_pred_validation, axis=1)
    y_true_validation = validation_generator.classes

    accuracy = np.mean(y_pred_validation_classes == y_true_validation)
    precision = precision_score(y_true_validation, y_pred_validation_classes, average='weighted')
    recall = recall_score(y_true_validation, y_pred_validation_classes, average='weighted')
    f1 = f1_score(y_true_validation, y_pred_validation_classes, average='weighted')

    print(f'Accuracy: ', accuracy)
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1-score: {f1:.4f}')

def save_model(model, filename):
    """Save the model to a file and print the file path."""
    model.save(filename)
    if os.path.exists(filename):
        print(f"Model saved successfully in {filename}")
    else:
        print("Error in saving the model")

    full_path = os.path.abspath(filename)
    print(f"Model saved at: {full_path}")

plot_history(history)
plot_confusion_matrices(model, train_generator, validation_generator, classes)
calculate_and_print_metrics(model, validation_generator)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 332ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step
# Accuracy:  0.5380710659898477
# Precision: 0.5383
# Recall: 0.5381
# F1-score: 0.5378

# %%
save_model(model, 'one_piece_character_classifier3.h5')

save_history(history, 'history_object3.pkl')
loaded_history = load_history('history_object3.pkl')

#acc = loaded_history['acc']
#loss = loaded_history['loss']
# Out:
# 2024-06-02 23:52:56,078 - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully in one_piece_character_classifier3.h5
# Model saved at: c:\Users\oscar\Github\Desarrollo-de-aplicaciones-avanzadas-de-ciencias-computacionales-TC3002B\Inteligencia Artificial\one_piece_character_classifier3.h5
# History object saved successfully in history_object3.pkl
# History object loaded successfully from history_object3.pkl

# %%
import keras
import requests
from io import BytesIO
from keras.models import  load_model

def download_image(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    return img

def preprocess_image_for_model(img, target_size=(150, 150)):
    img = img.resize(target_size)
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

def predict_image(model, img_url, classes):
    img = download_image(img_url)
    preprocessed_img = preprocess_image_for_model(img)
    predictions = model.predict(preprocessed_img)
    predicted_class_idx = np.argmax(predictions)
    predicted_class = classes[predicted_class_idx]

    print(f"Predicted class: {predicted_class}")
    print("Prediction probabilities:")
    for class_idx, class_name in classes.items():
        print(f"{class_name}: {predictions[0][class_idx]:.4f}")

    return predicted_class, predictions[0]

model = load_model("Models/one_piece_character_classifier3.h5")
image_url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSjFezNKkojzTJxht-H7yfFrS38Wd76k6Tq9w&s'
    
predicted_class, prediction_probs = predict_image(model, image_url, classes)
# Out:
# 2024-06-03 12:06:51,280 - WARNING - Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step
# Predicted class: Chopper
# Prediction probabilities:
# Chopper: 0.8935
# Jinbei: 0.1382
