# %%
import os
import shutil
import numpy as np
import pickle
import keras
from sklearn.metrics import precision_score, recall_score, f1_score
import logging
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import os

classes = {}

def create_directories(base_dir, categories):
    """
    Create directories for training, testing, and validation datasets.

    Parameters:
    - base_dir (str): The base directory where the train, test, and validation directories will be created.
    - categories (list): List of category names (sub-directory names) to create inside each of train, test, and validation directories.
    """
    for subset in ['train', 'test', 'validation']:
        for category in categories:
            dir_path = os.path.join(base_dir, subset, category)
            os.makedirs(dir_path, exist_ok=True)
            logging.info(f'Created directory: {dir_path}')

def copy_images(source_dir, images, dest_dir):
    """
    Copy images from source directory to destination directory.

    Parameters:
    - source_dir (str): The directory containing the source images.
    - images (list): List of image filenames to copy.
    - dest_dir (str): The destination directory where images will be copied.
    """
    for image in images:
        shutil.copy(os.path.join(source_dir, image), os.path.join(dest_dir, image))
        logging.info(f'Copied {image} to {dest_dir}')

def split_dataset(source_dir, base_dir, split_ratios=(0.7, 0.15, 0.15)):
    """
    Split the dataset into training, testing, and validation sets.

    Parameters:
    - source_dir (str): The source directory containing subdirectories of images for each category.
    - base_dir (str): The base directory where the split datasets will be stored.
    - split_ratios (tuple): A tuple containing the ratios for splitting the dataset into train, test, and validation sets.

    Raises:
    - ValueError: If the split ratios do not sum to 1.
    """
    if sum(split_ratios) != 1:
        raise ValueError("Split ratios must sum to 1. Provided ratios sum to {:.2f}".format(sum(split_ratios)))
    
    categories = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
    create_directories(base_dir, categories)

    for category in categories:
        category_path = os.path.join(source_dir, category)
        images = os.listdir(category_path)
        np.random.shuffle(images)

        train_split = int(len(images) * split_ratios[0])
        test_split = int(len(images) * split_ratios[1])

        train_images = images[:train_split]
        test_images = images[train_split:train_split + test_split]
        validation_images = images[train_split + test_split:]

        copy_images(category_path, train_images, os.path.join(base_dir, 'train', category))
        copy_images(category_path, test_images, os.path.join(base_dir, 'test', category))
        copy_images(category_path, validation_images, os.path.join(base_dir, 'validation', category))
        
def preprocess_image(image_path):
    img = Image.open(image_path)
    if img.mode == 'P' and 'transparency' in img.info:
        img = img.convert('RGBA')
        img = img.convert('RGB')
    if img.mode == 'RGBA':
        img = img.convert('RGB')
    return img

def setup_and_split_dataset(source_dir='Data', base_dir='Dataset_Split', split_ratios=(0.7, 0.15, 0.15)):
    """
    Set up logging, define directories, and split the dataset.

    Parameters:
    - source_dir (str): The source directory containing subdirectories of images for each category.
    - base_dir (str): The base directory where the split datasets will be stored.
    - split_ratios (tuple): A tuple containing the ratios for splitting the dataset into train, test, and validation sets.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    try:
        split_dataset(source_dir, base_dir, split_ratios)
    except ValueError as e:
        logging.error(e)
        
def load_dataset(base_dir, target_size=(150, 150), batch_size=32, augmentation=False):
    """
    Load the dataset into variables using ImageDataGenerator.

    Parameters:
    - base_dir (str): The base directory where the split datasets are stored.
    - target_size (tuple): The dimensions to which all images found will be resized.
    - batch_size (int): Size of the batches of data (default: 32).
    - augmentation (bool): Whether to apply data augmentation to the training dataset (default: False).

    Returns:
    - train_generator (DirectoryIterator): Iterator for training dataset.
    - test_generator (DirectoryIterator): Iterator for testing dataset.
    - validation_generator (DirectoryIterator): Iterator for validation dataset.
    """
    if augmentation:
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=90,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True)
    else:
        train_datagen = ImageDataGenerator(rescale=1./255)

    test_datagen = ImageDataGenerator(rescale=1./255)
    validation_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(
        os.path.join(base_dir, 'train'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    test_generator = test_datagen.flow_from_directory(
        os.path.join(base_dir, 'test'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    validation_generator = validation_datagen.flow_from_directory(
        os.path.join(base_dir, 'validation'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    return train_generator, test_generator, validation_generator

def display_images(images, labels, classes, num_images=9):
    num_images = min(num_images, len(images), len(labels))
    grid_size = int(np.ceil(np.sqrt(num_images)))
    plt.figure(figsize=(10, 10))
    
    for i in range(num_images):
        ax = plt.subplot(grid_size, grid_size, i + 1)
        image = images[i]

        if image.shape[-1] == 3:
            image = np.clip(image * 255, 0, 255).astype("uint8")

        plt.imshow(image)
        
        # Get the class name from the label
        class_name = classes[labels[i].argmax()] if labels[i].ndim > 0 else classes[labels[i]]
        plt.title(f"Label: {class_name}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    setup_and_split_dataset()
    
    base_dir = 'Dataset_Split'
    train_generator, test_generator, validation_generator = load_dataset(base_dir, augmentation=True)
    
    classes = {v: k for k, v in train_generator.class_indices.items()}

    images, labels = next(train_generator)
    display_images(images, labels, classes)
# Out:
# 2024-06-02 22:54:13,788 - INFO - Created directory: Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,789 - INFO - Created directory: Dataset_Split\train\Jinbei
# 2024-06-02 22:54:13,789 - INFO - Created directory: Dataset_Split\test\Chopper
# 2024-06-02 22:54:13,790 - INFO - Created directory: Dataset_Split\test\Jinbei
# 2024-06-02 22:54:13,791 - INFO - Created directory: Dataset_Split\validation\Chopper
# 2024-06-02 22:54:13,791 - INFO - Created directory: Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:13,794 - INFO - Copied 145.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,795 - INFO - Copied 53.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,796 - INFO - Copied modified_78.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,797 - INFO - Copied 76.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,799 - INFO - Copied modified_184.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,800 - INFO - Copied modified_44.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,801 - INFO - Copied modified_46.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,802 - INFO - Copied 134.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,804 - INFO - Copied 18.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,805 - INFO - Copied 7.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,806 - INFO - Copied 5.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,807 - INFO - Copied modified_49.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,808 - INFO - Copied 96.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,809 - INFO - Copied 62.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,810 - INFO - Copied 127.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,811 - INFO - Copied 80.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,813 - INFO - Copied modified_54.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,814 - INFO - Copied 51.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,815 - INFO - Copied 50.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,816 - INFO - Copied 189.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,817 - INFO - Copied 212.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,818 - INFO - Copied 99.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,820 - INFO - Copied modified_138.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,821 - INFO - Copied modified_116.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,822 - INFO - Copied 198.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,823 - INFO - Copied 89.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,824 - INFO - Copied 193.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,825 - INFO - Copied 210.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,826 - INFO - Copied modified_191.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,827 - INFO - Copied 112.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,829 - INFO - Copied 167.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,830 - INFO - Copied 115.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,831 - INFO - Copied modified_33.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,832 - INFO - Copied 206.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,834 - INFO - Copied modified_214.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,835 - INFO - Copied modified_65.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,836 - INFO - Copied 185.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,837 - INFO - Copied 48.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,838 - INFO - Copied 196.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,840 - INFO - Copied modified_97.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,841 - INFO - Copied 10.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,842 - INFO - Copied modified_161.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,843 - INFO - Copied 164.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,844 - INFO - Copied modified_158.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,846 - INFO - Copied 132.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,847 - INFO - Copied 170.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,848 - INFO - Copied 35.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,849 - INFO - Copied modified_73.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,850 - INFO - Copied 70.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,852 - INFO - Copied modified_174.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,853 - INFO - Copied 165.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,854 - INFO - Copied 90.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,855 - INFO - Copied 173.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,856 - INFO - Copied modified_68.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,858 - INFO - Copied 158.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,859 - INFO - Copied modified_156.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,860 - INFO - Copied 156.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,862 - INFO - Copied 132.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,863 - INFO - Copied 203.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,865 - INFO - Copied modified_32.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,866 - INFO - Copied 152.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,867 - INFO - Copied modified_210.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,868 - INFO - Copied 173.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,869 - INFO - Copied 45.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,870 - INFO - Copied 78.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,872 - INFO - Copied 142.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,873 - INFO - Copied 182.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,874 - INFO - Copied 183.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,876 - INFO - Copied 112.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,877 - INFO - Copied 27.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,878 - INFO - Copied 107.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,880 - INFO - Copied modified_83.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,881 - INFO - Copied modified_15.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,882 - INFO - Copied 96.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,884 - INFO - Copied 136.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,885 - INFO - Copied 201.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,886 - INFO - Copied 205.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,888 - INFO - Copied 47.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,889 - INFO - Copied modified_127.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,890 - INFO - Copied modified_205.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,892 - INFO - Copied modified_198.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,893 - INFO - Copied 166.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,895 - INFO - Copied modified_13.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,896 - INFO - Copied 123.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,897 - INFO - Copied modified_173.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,899 - INFO - Copied 197.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,900 - INFO - Copied modified_100.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,901 - INFO - Copied 149.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,902 - INFO - Copied 9.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,904 - INFO - Copied 189.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,905 - INFO - Copied modified_171.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,906 - INFO - Copied 74.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,908 - INFO - Copied 46.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,909 - INFO - Copied modified_106.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,910 - INFO - Copied 72.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,911 - INFO - Copied modified_11.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,912 - INFO - Copied 4.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,913 - INFO - Copied 140.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,915 - INFO - Copied 68.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,916 - INFO - Copied 162.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,917 - INFO - Copied 171.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,919 - INFO - Copied 215.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,920 - INFO - Copied modified_189.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,921 - INFO - Copied 84.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,922 - INFO - Copied 195.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,924 - INFO - Copied 31.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,925 - INFO - Copied 38.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,926 - INFO - Copied modified_146.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,928 - INFO - Copied modified_43.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,929 - INFO - Copied modified_162.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,930 - INFO - Copied 55.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,931 - INFO - Copied modified_202.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,932 - INFO - Copied 34.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,934 - INFO - Copied 94.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,935 - INFO - Copied 23.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,936 - INFO - Copied modified_102.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,938 - INFO - Copied modified_175.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,939 - INFO - Copied modified_133.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,940 - INFO - Copied modified_132.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,942 - INFO - Copied 85.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,943 - INFO - Copied 28.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,944 - INFO - Copied modified_160.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,945 - INFO - Copied 182.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,947 - INFO - Copied modified_5.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,948 - INFO - Copied 67.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,949 - INFO - Copied modified_63.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,950 - INFO - Copied modified_134.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,952 - INFO - Copied modified_1.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,953 - INFO - Copied 151.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,954 - INFO - Copied 124.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,955 - INFO - Copied 157.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,956 - INFO - Copied 88.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,958 - INFO - Copied 113.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,959 - INFO - Copied 1.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,960 - INFO - Copied 69.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,962 - INFO - Copied 79.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,963 - INFO - Copied modified_16.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,964 - INFO - Copied 123.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,965 - INFO - Copied 62.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,967 - INFO - Copied 8.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,968 - INFO - Copied 39.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,969 - INFO - Copied modified_187.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,970 - INFO - Copied 114.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,971 - INFO - Copied 148.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,973 - INFO - Copied 188.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,974 - INFO - Copied 81.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,975 - INFO - Copied 102.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,977 - INFO - Copied 59.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,978 - INFO - Copied 12.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,980 - INFO - Copied modified_26.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,982 - INFO - Copied modified_167.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,984 - INFO - Copied modified_25.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,985 - INFO - Copied 162.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,986 - INFO - Copied 80.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,988 - INFO - Copied 127.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,989 - INFO - Copied 213.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,990 - INFO - Copied 170.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,991 - INFO - Copied modified_14.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,992 - INFO - Copied 66.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,993 - INFO - Copied 216.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,995 - INFO - Copied modified_29.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,996 - INFO - Copied 104.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,998 - INFO - Copied modified_40.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:13,999 - INFO - Copied 77.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,000 - INFO - Copied 106.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,002 - INFO - Copied modified_12.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,003 - INFO - Copied 115.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,004 - INFO - Copied modified_139.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,005 - INFO - Copied 40.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,007 - INFO - Copied 3.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,008 - INFO - Copied 99.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,009 - INFO - Copied 95.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,011 - INFO - Copied 72.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,012 - INFO - Copied modified_194.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,013 - INFO - Copied modified_3.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,014 - INFO - Copied 37.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,015 - INFO - Copied modified_51.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,017 - INFO - Copied 39.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,018 - INFO - Copied modified_182.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,019 - INFO - Copied modified_165.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,020 - INFO - Copied 70.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,021 - INFO - Copied 32.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,023 - INFO - Copied 187.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,024 - INFO - Copied 67.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,025 - INFO - Copied 87.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,026 - INFO - Copied 163.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,027 - INFO - Copied 130.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,029 - INFO - Copied 117.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,030 - INFO - Copied 153.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,031 - INFO - Copied 75.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,032 - INFO - Copied 194.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,033 - INFO - Copied modified_125.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,035 - INFO - Copied modified_66.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,036 - INFO - Copied 188.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,037 - INFO - Copied 57.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,038 - INFO - Copied 125.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,040 - INFO - Copied 15.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,041 - INFO - Copied modified_81.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,042 - INFO - Copied 92.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,044 - INFO - Copied 187.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,045 - INFO - Copied modified_170.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,046 - INFO - Copied modified_31.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,047 - INFO - Copied modified_36.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,049 - INFO - Copied 138.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,050 - INFO - Copied modified_79.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,051 - INFO - Copied 118.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,052 - INFO - Copied 21.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,054 - INFO - Copied 160.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,055 - INFO - Copied modified_28.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,056 - INFO - Copied 65.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,057 - INFO - Copied 110.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,059 - INFO - Copied 212.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,060 - INFO - Copied modified_155.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,061 - INFO - Copied modified_120.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,062 - INFO - Copied modified_47.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,063 - INFO - Copied modified_117.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,065 - INFO - Copied 52.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,066 - INFO - Copied 186.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,067 - INFO - Copied 211.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,068 - INFO - Copied modified_92.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,069 - INFO - Copied 10.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,071 - INFO - Copied 176.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,072 - INFO - Copied modified_72.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,073 - INFO - Copied 2.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,075 - INFO - Copied 18.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,076 - INFO - Copied modified_140.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,077 - INFO - Copied modified_129.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,079 - INFO - Copied 83.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,080 - INFO - Copied 24.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,081 - INFO - Copied 9.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,082 - INFO - Copied modified_147.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,084 - INFO - Copied 120.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,085 - INFO - Copied 129.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,086 - INFO - Copied 32.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,088 - INFO - Copied 38.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,089 - INFO - Copied 55.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,090 - INFO - Copied modified_213.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,092 - INFO - Copied modified_20.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,093 - INFO - Copied modified_88.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,094 - INFO - Copied 22.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,095 - INFO - Copied 152.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,096 - INFO - Copied 5.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,098 - INFO - Copied 184.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,099 - INFO - Copied 174.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,100 - INFO - Copied modified_130.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,102 - INFO - Copied 211.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,103 - INFO - Copied modified_207.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,104 - INFO - Copied 206.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,105 - INFO - Copied modified_216.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,107 - INFO - Copied 63.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,108 - INFO - Copied 129.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,109 - INFO - Copied 35.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,110 - INFO - Copied 26.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,111 - INFO - Copied 46.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,113 - INFO - Copied 13.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,114 - INFO - Copied modified_199.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,115 - INFO - Copied modified_128.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,116 - INFO - Copied 41.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,118 - INFO - Copied 180.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,119 - INFO - Copied modified_108.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,120 - INFO - Copied 105.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,121 - INFO - Copied 76.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,122 - INFO - Copied 168.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,123 - INFO - Copied 8.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,125 - INFO - Copied 105.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,126 - INFO - Copied 119.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,127 - INFO - Copied 133.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,129 - INFO - Copied 144.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,130 - INFO - Copied 44.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,131 - INFO - Copied modified_104.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,132 - INFO - Copied modified_38.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,133 - INFO - Copied 135.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,134 - INFO - Copied modified_34.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,136 - INFO - Copied 30.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,137 - INFO - Copied modified_212.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,138 - INFO - Copied 153.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,139 - INFO - Copied modified_163.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,141 - INFO - Copied modified_50.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,142 - INFO - Copied 78.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,143 - INFO - Copied 98.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,144 - INFO - Copied 126.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,146 - INFO - Copied 51.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,147 - INFO - Copied 169.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,148 - INFO - Copied 13.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,149 - INFO - Copied 98.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,151 - INFO - Copied modified_45.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,152 - INFO - Copied modified_80.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,153 - INFO - Copied 140.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,154 - INFO - Copied 82.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,156 - INFO - Copied 198.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,157 - INFO - Copied modified_62.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,158 - INFO - Copied 87.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,160 - INFO - Copied modified_107.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,161 - INFO - Copied 180.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,162 - INFO - Copied modified_21.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,163 - INFO - Copied 89.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,164 - INFO - Copied modified_96.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,165 - INFO - Copied modified_196.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,167 - INFO - Copied modified_90.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,168 - INFO - Copied 148.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,170 - INFO - Copied 141.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,171 - INFO - Copied modified_164.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,172 - INFO - Copied 69.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,173 - INFO - Copied 16.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,174 - INFO - Copied 193.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,176 - INFO - Copied modified_204.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,177 - INFO - Copied 61.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,179 - INFO - Copied 126.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,180 - INFO - Copied 128.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,181 - INFO - Copied 116.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,182 - INFO - Copied modified_4.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,183 - INFO - Copied 11.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,185 - INFO - Copied modified_64.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,186 - INFO - Copied modified_77.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,187 - INFO - Copied 155.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,189 - INFO - Copied 56.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,190 - INFO - Copied modified_181.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,191 - INFO - Copied modified_99.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,192 - INFO - Copied modified_208.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,193 - INFO - Copied 95.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,194 - INFO - Copied modified_123.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,196 - INFO - Copied 158.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,197 - INFO - Copied modified_56.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,198 - INFO - Copied 138.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,200 - INFO - Copied 122.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,201 - INFO - Copied 116.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,204 - INFO - Copied 114.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,207 - INFO - Copied 124.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,209 - INFO - Copied 16.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,210 - INFO - Copied modified_87.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,212 - INFO - Copied 204.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,214 - INFO - Copied modified_145.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,215 - INFO - Copied 102.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,217 - INFO - Copied 137.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,219 - INFO - Copied 202.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,220 - INFO - Copied 88.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,222 - INFO - Copied 190.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,223 - INFO - Copied 196.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,224 - INFO - Copied 179.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,226 - INFO - Copied modified_126.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,227 - INFO - Copied modified_2.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,229 - INFO - Copied 172.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,231 - INFO - Copied 6.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,232 - INFO - Copied 17.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,234 - INFO - Copied modified_48.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,235 - INFO - Copied modified_203.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,236 - INFO - Copied 166.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,238 - INFO - Copied 179.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,239 - INFO - Copied modified_98.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,240 - INFO - Copied 24.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,241 - INFO - Copied 25.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,242 - INFO - Copied 208.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,244 - INFO - Copied 205.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,245 - INFO - Copied 146.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,246 - INFO - Copied 159.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,248 - INFO - Copied 20.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,249 - INFO - Copied 131.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,250 - INFO - Copied modified_190.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,252 - INFO - Copied 77.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,253 - INFO - Copied 199.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,254 - INFO - Copied 59.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,255 - INFO - Copied 197.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,256 - INFO - Copied 146.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,257 - INFO - Copied 214.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,259 - INFO - Copied 29.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,260 - INFO - Copied modified_23.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,261 - INFO - Copied 136.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,262 - INFO - Copied modified_59.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,263 - INFO - Copied 110.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,265 - INFO - Copied 81.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,266 - INFO - Copied modified_113.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,267 - INFO - Copied modified_122.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,268 - INFO - Copied 11.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,269 - INFO - Copied 25.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,270 - INFO - Copied 143.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,271 - INFO - Copied modified_53.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,273 - INFO - Copied 133.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,274 - INFO - Copied modified_111.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,275 - INFO - Copied modified_119.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,276 - INFO - Copied 42.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,278 - INFO - Copied 174.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,279 - INFO - Copied 200.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,280 - INFO - Copied modified_42.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,281 - INFO - Copied modified_41.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,283 - INFO - Copied modified_141.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,284 - INFO - Copied 19.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,285 - INFO - Copied modified_27.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,286 - INFO - Copied 139.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,288 - INFO - Copied 93.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,289 - INFO - Copied 58.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,290 - INFO - Copied 64.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,291 - INFO - Copied 40.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,293 - INFO - Copied 73.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,294 - INFO - Copied 20.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,296 - INFO - Copied modified_89.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,297 - INFO - Copied 6.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,298 - INFO - Copied 207.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,299 - INFO - Copied 91.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,301 - INFO - Copied modified_176.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,302 - INFO - Copied 128.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,303 - INFO - Copied modified_112.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,304 - INFO - Copied modified_172.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,305 - INFO - Copied 125.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,307 - INFO - Copied 131.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,308 - INFO - Copied 90.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,309 - INFO - Copied modified_8.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,310 - INFO - Copied modified_124.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,311 - INFO - Copied modified_151.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,312 - INFO - Copied 23.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,314 - INFO - Copied 190.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,315 - INFO - Copied 83.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,316 - INFO - Copied 84.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,318 - INFO - Copied modified_110.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,319 - INFO - Copied 100.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,320 - INFO - Copied 186.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,321 - INFO - Copied 109.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,323 - INFO - Copied 172.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,324 - INFO - Copied 36.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,325 - INFO - Copied 37.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,326 - INFO - Copied 164.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,328 - INFO - Copied 91.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,329 - INFO - Copied 34.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,330 - INFO - Copied 147.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,331 - INFO - Copied modified_197.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,333 - INFO - Copied 33.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,334 - INFO - Copied modified_121.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,335 - INFO - Copied 45.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,337 - INFO - Copied 41.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,338 - INFO - Copied 17.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,339 - INFO - Copied 30.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,340 - INFO - Copied modified_115.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,341 - INFO - Copied 100.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,343 - INFO - Copied 145.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,344 - INFO - Copied 215.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,345 - INFO - Copied 144.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,346 - INFO - Copied 22.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,348 - INFO - Copied 71.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,349 - INFO - Copied modified_101.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,350 - INFO - Copied 103.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,352 - INFO - Copied 15.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,353 - INFO - Copied 111.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,354 - INFO - Copied 106.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,355 - INFO - Copied 159.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,357 - INFO - Copied modified_154.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,358 - INFO - Copied 178.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,359 - INFO - Copied 101.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,360 - INFO - Copied modified_188.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,362 - INFO - Copied 216.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,363 - INFO - Copied 7.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,364 - INFO - Copied 194.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,366 - INFO - Copied 135.png_inverted.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,367 - INFO - Copied modified_144.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,368 - INFO - Copied 108.png to Dataset_Split\train\Chopper
# 2024-06-02 22:54:14,370 - INFO - Copied modified_82.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,371 - INFO - Copied 119.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,372 - INFO - Copied modified_86.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,373 - INFO - Copied 71.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,374 - INFO - Copied modified_168.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,376 - INFO - Copied 201.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,377 - INFO - Copied modified_200.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,379 - INFO - Copied modified_95.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,380 - INFO - Copied 165.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,381 - INFO - Copied 120.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,382 - INFO - Copied modified_85.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,384 - INFO - Copied 207.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,385 - INFO - Copied modified_67.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,386 - INFO - Copied modified_185.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,387 - INFO - Copied modified_74.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,389 - INFO - Copied 86.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,390 - INFO - Copied 134.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,391 - INFO - Copied 108.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,393 - INFO - Copied modified_17.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,394 - INFO - Copied 204.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,395 - INFO - Copied 54.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,397 - INFO - Copied 47.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,398 - INFO - Copied 154.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,399 - INFO - Copied modified_52.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,401 - INFO - Copied modified_193.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,402 - INFO - Copied modified_137.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,403 - INFO - Copied 50.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,404 - INFO - Copied modified_157.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,406 - INFO - Copied 209.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,407 - INFO - Copied modified_131.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,408 - INFO - Copied 157.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,409 - INFO - Copied modified_9.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,410 - INFO - Copied modified_177.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,412 - INFO - Copied modified_10.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,413 - INFO - Copied modified_35.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,414 - INFO - Copied 143.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,415 - INFO - Copied modified_61.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,417 - INFO - Copied modified_91.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,418 - INFO - Copied 154.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,420 - INFO - Copied 181.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,421 - INFO - Copied 49.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,422 - INFO - Copied modified_57.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,424 - INFO - Copied modified_19.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,425 - INFO - Copied 75.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,426 - INFO - Copied 161.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,427 - INFO - Copied 3.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,428 - INFO - Copied 195.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,430 - INFO - Copied 175.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,431 - INFO - Copied 43.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,432 - INFO - Copied 63.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,434 - INFO - Copied 36.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,435 - INFO - Copied 109.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,436 - INFO - Copied 49.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,437 - INFO - Copied modified_183.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,439 - INFO - Copied 58.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,440 - INFO - Copied 168.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,441 - INFO - Copied 177.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,442 - INFO - Copied 113.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,444 - INFO - Copied modified_7.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,445 - INFO - Copied 163.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,446 - INFO - Copied modified_186.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,447 - INFO - Copied 101.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,448 - INFO - Copied 209.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,450 - INFO - Copied modified_152.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,451 - INFO - Copied 171.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,452 - INFO - Copied 176.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,454 - INFO - Copied 64.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,455 - INFO - Copied modified_211.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,456 - INFO - Copied modified_135.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,457 - INFO - Copied modified_215.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,458 - INFO - Copied 29.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,460 - INFO - Copied modified_201.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,461 - INFO - Copied 202.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,462 - INFO - Copied modified_153.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,464 - INFO - Copied modified_142.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,467 - INFO - Copied modified_192.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,470 - INFO - Copied 97.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,473 - INFO - Copied modified_18.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,475 - INFO - Copied 104.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,477 - INFO - Copied 52.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,479 - INFO - Copied 44.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,481 - INFO - Copied modified_159.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,482 - INFO - Copied 65.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,484 - INFO - Copied 68.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,485 - INFO - Copied 31.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,487 - INFO - Copied modified_166.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,488 - INFO - Copied 213.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,489 - INFO - Copied 86.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,491 - INFO - Copied 60.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,492 - INFO - Copied 150.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,495 - INFO - Copied modified_178.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,496 - INFO - Copied 73.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,498 - INFO - Copied 103.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,499 - INFO - Copied 169.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,500 - INFO - Copied 93.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,502 - INFO - Copied 161.png_inverted.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,503 - INFO - Copied modified_69.png to Dataset_Split\test\Chopper
# 2024-06-02 22:54:14,504 - INFO - Copied 14.png_inverted.png to Dataset_Split\validation\Chopper
# 2024-06-02 22:54:14,505 - INFO - Copied modified_6.png to Dataset_Split\validation\Chopper
# 2024-06-02 22:54:14,507 - INFO - Copied 185.png_inverted.png to Dataset_Split\validation\Chopper
# 2024-06-02 22:54:14,508 - INFO - Copied 94.png_inverted.png to Dataset_Split\validation\Chopper
# ...
# 2024-06-02 22:54:15,416 - INFO - Copied modified187 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,418 - INFO - Copied modified183 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,420 - INFO - Copied 108.png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,421 - INFO - Copied 120.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,422 - INFO - Copied 23.jpeg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,424 - INFO - Copied 201 .png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,426 - INFO - Copied 112.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,427 - INFO - Copied 146.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,428 - INFO - Copied modified85.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,430 - INFO - Copied modified172 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,431 - INFO - Copied 174 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,433 - INFO - Copied 136.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,434 - INFO - Copied 53.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,435 - INFO - Copied modified162 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,437 - INFO - Copied 76.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,438 - INFO - Copied modified195 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,439 - INFO - Copied 177.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,441 - INFO - Copied modified28.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,442 - INFO - Copied modified100.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,443 - INFO - Copied modified115.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,445 - INFO - Copied 58.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,447 - INFO - Copied 198 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,448 - INFO - Copied 216.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,449 - INFO - Copied 4.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,451 - INFO - Copied 190 .png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,452 - INFO - Copied 212 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,453 - INFO - Copied modified201.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,455 - INFO - Copied 213.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,456 - INFO - Copied 9.png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,458 - INFO - Copied modified128.png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,460 - INFO - Copied 117.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,462 - INFO - Copied modified111.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,464 - INFO - Copied 54.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,465 - INFO - Copied modified84.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,467 - INFO - Copied modified28.png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,468 - INFO - Copied 195.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,470 - INFO - Copied 123.png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,471 - INFO - Copied 7.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,472 - INFO - Copied modified108.png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,474 - INFO - Copied 189 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,475 - INFO - Copied 99.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,476 - INFO - Copied 53.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,478 - INFO - Copied modified213 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,479 - INFO - Copied 214 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,480 - INFO - Copied 61.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,482 - INFO - Copied 116.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,483 - INFO - Copied 201.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,485 - INFO - Copied modified56.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,486 - INFO - Copied 181 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,488 - INFO - Copied 163 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,489 - INFO - Copied 106.png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,490 - INFO - Copied 4.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,492 - INFO - Copied 87.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,494 - INFO - Copied modified142.png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,496 - INFO - Copied 41.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,497 - INFO - Copied modified156 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,498 - INFO - Copied 28.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,500 - INFO - Copied 23.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,501 - INFO - Copied 79.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,502 - INFO - Copied 153 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,504 - INFO - Copied 170 .png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,505 - INFO - Copied modified130.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,506 - INFO - Copied modified207.png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,508 - INFO - Copied 65.jpeg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,510 - INFO - Copied 91.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,514 - INFO - Copied modified4.png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,517 - INFO - Copied 68.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,519 - INFO - Copied 208 .png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,522 - INFO - Copied 40.jpg_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,524 - INFO - Copied modified20.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,525 - INFO - Copied modified173 .png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,528 - INFO - Copied 21.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,529 - INFO - Copied 166 .png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,532 - INFO - Copied 83.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,534 - INFO - Copied modified72.png.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,536 - INFO - Copied 77.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,537 - INFO - Copied 135.png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,539 - INFO - Copied 171 .png_inverted.png to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,540 - INFO - Copied modified15.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,542 - INFO - Copied modified96.jpg.jpg to Dataset_Split\test\Jinbei
# 2024-06-02 22:54:15,545 - INFO - Copied 27.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,546 - INFO - Copied modified202 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,548 - INFO - Copied 159.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,549 - INFO - Copied modified189.png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,551 - INFO - Copied 179 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,552 - INFO - Copied 158 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,553 - INFO - Copied 183 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,555 - INFO - Copied 35.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,558 - INFO - Copied modified39.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,559 - INFO - Copied modified174 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,561 - INFO - Copied 148.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,562 - INFO - Copied modified76.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,564 - INFO - Copied 114.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,565 - INFO - Copied modified61.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,566 - INFO - Copied 148 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,568 - INFO - Copied 88.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,569 - INFO - Copied modified141.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,570 - INFO - Copied 102.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,572 - INFO - Copied modified121.png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,573 - INFO - Copied modified99.jpeg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,574 - INFO - Copied 143.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,576 - INFO - Copied modified129.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,577 - INFO - Copied modified167 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,578 - INFO - Copied 141.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,580 - INFO - Copied 161 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,581 - INFO - Copied 112.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,582 - INFO - Copied 84.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,585 - INFO - Copied 93.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,586 - INFO - Copied 184 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,590 - INFO - Copied 111.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,592 - INFO - Copied 131.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,593 - INFO - Copied modified95.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,594 - INFO - Copied 216.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,595 - INFO - Copied 42.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,597 - INFO - Copied modified17.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,598 - INFO - Copied 133.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,599 - INFO - Copied 72.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,601 - INFO - Copied 162 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,602 - INFO - Copied 135.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,603 - INFO - Copied 170 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,605 - INFO - Copied modified9.png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,607 - INFO - Copied 186 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,608 - INFO - Copied 15.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,609 - INFO - Copied modified12.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,610 - INFO - Copied 13.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,612 - INFO - Copied modified147.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,613 - INFO - Copied 204 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,615 - INFO - Copied modified194 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,616 - INFO - Copied 49.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,618 - INFO - Copied 194 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,619 - INFO - Copied 156 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,620 - INFO - Copied 156.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,622 - INFO - Copied modified33.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,623 - INFO - Copied modified37.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,626 - INFO - Copied 12.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,627 - INFO - Copied modified199 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,628 - INFO - Copied 153 .png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,630 - INFO - Copied 61.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,631 - INFO - Copied 192 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,632 - INFO - Copied 191 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,634 - INFO - Copied 202 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,635 - INFO - Copied modified148 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,636 - INFO - Copied modified102.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,638 - INFO - Copied modified122.png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,639 - INFO - Copied modified208 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,641 - INFO - Copied modified168 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,642 - INFO - Copied modified55.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,644 - INFO - Copied 49.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,645 - INFO - Copied 48.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,647 - INFO - Copied 12.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,649 - INFO - Copied 4.png_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,651 - INFO - Copied 14.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,653 - INFO - Copied modified164 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,655 - INFO - Copied 147.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,656 - INFO - Copied modified68.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,657 - INFO - Copied modified196 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,659 - INFO - Copied modified14.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,660 - INFO - Copied 171 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,662 - INFO - Copied 209.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,663 - INFO - Copied modified5.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,667 - INFO - Copied modified53.jpg.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,669 - INFO - Copied 177 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,671 - INFO - Copied 213.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,674 - INFO - Copied 20.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,676 - INFO - Copied modified191 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,678 - INFO - Copied 98.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,679 - INFO - Copied 69.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,681 - INFO - Copied modified123.png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,683 - INFO - Copied 1.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,685 - INFO - Copied modified201 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,686 - INFO - Copied 100.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,688 - INFO - Copied 105.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,690 - INFO - Copied 93.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,691 - INFO - Copied 184 .png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,693 - INFO - Copied 130.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,695 - INFO - Copied 129.jpg to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,697 - INFO - Copied modified153 .png.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,699 - INFO - Copied 121.jpg_inverted.png to Dataset_Split\validation\Jinbei
# 2024-06-02 22:54:15,700 - INFO - Copied 125.jpg_inverted.png to Dataset_Split\validation\Jinbei
# Found 908 images belonging to 2 classes.
# Found 194 images belonging to 2 classes.
# Found 197 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D((2, 2)),  # Capa de pooling

    # Capa convolucional con 128 filtros y función de activación ReLU
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),  # Capa de pooling

    # Capa convolucional con 256 filtros y función de activación ReLU
    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),  # Capa de pooling

    # Capa convolucional con 512 filtros y función de activación ReLU
    Conv2D(512, (3, 3), activation='relu'),

    Flatten(),  # Aplanar la salida para conectarla a capas densas

    # Capa densa con 512 neuronas y función de activación ReLU
    Dense(512, activation='relu'),

    # Capa densa de salida con activación sigmoide para clasificación binaria
    Dense(len(train_generator.class_indices), activation='sigmoid')
])

# Compilar el modelo con el optimizador Adam y una tasa de aprendizaje reducida
opt = Adam(learning_rate=0.0005)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=opt)

# Muestra el resumen del modelo
model.summary()
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 148, 148, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 74, 74, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 72, 72, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 36, 36, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 34, 34, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 17, 17, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 15, 15, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │    58,982,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,534,914 (230.92 MB)
#  Trainable params: 60,534,914 (230.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_generator, epochs=50, validation_data=validation_generator)
# Out:
# Epoch 1/50
# c:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# c:\Python312\Lib\site-packages\PIL\Image.py:1000: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.4843 - loss: 1.2175 - val_accuracy: 0.5025 - val_loss: 0.6931
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 926ms/step - accuracy: 0.5136 - loss: 0.6928 - val_accuracy: 0.4975 - val_loss: 0.7014
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 959ms/step - accuracy: 0.5310 - loss: 0.6906 - val_accuracy: 0.5076 - val_loss: 0.6928
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 932ms/step - accuracy: 0.5587 - loss: 0.6827 - val_accuracy: 0.5990 - val_loss: 0.6572
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.6367 - loss: 0.6409 - val_accuracy: 0.6853 - val_loss: 0.5992
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 930ms/step - accuracy: 0.7236 - loss: 0.5578 - val_accuracy: 0.7563 - val_loss: 0.4656
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 934ms/step - accuracy: 0.7746 - loss: 0.4544 - val_accuracy: 0.7411 - val_loss: 0.5279
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 941ms/step - accuracy: 0.8121 - loss: 0.4387 - val_accuracy: 0.7970 - val_loss: 0.4138
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.8172 - loss: 0.4271 - val_accuracy: 0.8071 - val_loss: 0.4260
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 940ms/step - accuracy: 0.8424 - loss: 0.3755 - val_accuracy: 0.7411 - val_loss: 0.6302
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 978ms/step - accuracy: 0.8422 - loss: 0.3465 - val_accuracy: 0.8782 - val_loss: 0.2907
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 939ms/step - accuracy: 0.8775 - loss: 0.3273 - val_accuracy: 0.8528 - val_loss: 0.3057
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 938ms/step - accuracy: 0.8726 - loss: 0.3053 - val_accuracy: 0.8579 - val_loss: 0.3839
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 933ms/step - accuracy: 0.8848 - loss: 0.2820 - val_accuracy: 0.7665 - val_loss: 0.5120
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 943ms/step - accuracy: 0.8667 - loss: 0.3356 - val_accuracy: 0.8274 - val_loss: 0.3906
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 933ms/step - accuracy: 0.8616 - loss: 0.3137 - val_accuracy: 0.9137 - val_loss: 0.2376
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.8741 - loss: 0.2989 - val_accuracy: 0.9086 - val_loss: 0.2418
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 932ms/step - accuracy: 0.9029 - loss: 0.2281 - val_accuracy: 0.9239 - val_loss: 0.2313
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 923ms/step - accuracy: 0.9171 - loss: 0.2207 - val_accuracy: 0.9137 - val_loss: 0.1947
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.9174 - loss: 0.2136 - val_accuracy: 0.9036 - val_loss: 0.2149
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 932ms/step - accuracy: 0.9142 - loss: 0.2136 - val_accuracy: 0.9239 - val_loss: 0.2009
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.9235 - loss: 0.2162 - val_accuracy: 0.8680 - val_loss: 0.2804
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 938ms/step - accuracy: 0.9164 - loss: 0.2406 - val_accuracy: 0.9036 - val_loss: 0.2212
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 930ms/step - accuracy: 0.8899 - loss: 0.2611 - val_accuracy: 0.8579 - val_loss: 0.3416
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 952ms/step - accuracy: 0.9035 - loss: 0.2545 - val_accuracy: 0.8934 - val_loss: 0.2717
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 965ms/step - accuracy: 0.9119 - loss: 0.2159 - val_accuracy: 0.9137 - val_loss: 0.2493
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 939ms/step - accuracy: 0.9259 - loss: 0.2078 - val_accuracy: 0.9239 - val_loss: 0.2282
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 943ms/step - accuracy: 0.9281 - loss: 0.1954 - val_accuracy: 0.9188 - val_loss: 0.2311
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 951ms/step - accuracy: 0.9536 - loss: 0.1394 - val_accuracy: 0.9086 - val_loss: 0.2554
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 978ms/step - accuracy: 0.9324 - loss: 0.1632 - val_accuracy: 0.9086 - val_loss: 0.2392
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 935ms/step - accuracy: 0.9350 - loss: 0.1841 - val_accuracy: 0.9391 - val_loss: 0.2186
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 923ms/step - accuracy: 0.9195 - loss: 0.2007 - val_accuracy: 0.8832 - val_loss: 0.3000
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 941ms/step - accuracy: 0.9064 - loss: 0.2246 - val_accuracy: 0.9086 - val_loss: 0.2645
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 952ms/step - accuracy: 0.8716 - loss: 0.2928 - val_accuracy: 0.8934 - val_loss: 0.2315
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 950ms/step - accuracy: 0.9507 - loss: 0.1417 - val_accuracy: 0.9188 - val_loss: 0.1960
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 946ms/step - accuracy: 0.9402 - loss: 0.1551 - val_accuracy: 0.9188 - val_loss: 0.1792
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 937ms/step - accuracy: 0.9391 - loss: 0.1676 - val_accuracy: 0.8934 - val_loss: 0.2510
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 936ms/step - accuracy: 0.9302 - loss: 0.1926 - val_accuracy: 0.9340 - val_loss: 0.1592
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 940ms/step - accuracy: 0.9336 - loss: 0.1769 - val_accuracy: 0.9391 - val_loss: 0.1146
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 940ms/step - accuracy: 0.9594 - loss: 0.1186 - val_accuracy: 0.8731 - val_loss: 0.3442
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 970ms/step - accuracy: 0.8979 - loss: 0.2245 - val_accuracy: 0.9340 - val_loss: 0.1863
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 937ms/step - accuracy: 0.9366 - loss: 0.1483 - val_accuracy: 0.9239 - val_loss: 0.2575
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 30s 950ms/step - accuracy: 0.9563 - loss: 0.1173 - val_accuracy: 0.9442 - val_loss: 0.1384
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 935ms/step - accuracy: 0.9677 - loss: 0.0848 - val_accuracy: 0.9391 - val_loss: 0.1381
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 934ms/step - accuracy: 0.9539 - loss: 0.1207 - val_accuracy: 0.9239 - val_loss: 0.1985
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 934ms/step - accuracy: 0.9399 - loss: 0.1614 - val_accuracy: 0.9188 - val_loss: 0.2335
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 954ms/step - accuracy: 0.9463 - loss: 0.1336 - val_accuracy: 0.9340 - val_loss: 0.1473
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 928ms/step - accuracy: 0.9459 - loss: 0.1238 - val_accuracy: 0.9137 - val_loss: 0.4027
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 28s 931ms/step - accuracy: 0.9300 - loss: 0.1570 - val_accuracy: 0.9086 - val_loss: 0.1683
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 29s 927ms/step - accuracy: 0.9490 - loss: 0.1276 - val_accuracy: 0.9340 - val_loss: 0.1853

# %%
def plot_history(history):
    training_accuracy = history.history['accuracy']
    validation_accuracy = history.history['val_accuracy']
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].plot(training_accuracy, label='Training Accuracy', color='blue', linestyle='-', marker='o')
    axes[0].plot(validation_accuracy, label='Validation Accuracy', color='green', linestyle='-', marker='o')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()

    axes[1].plot(training_loss, label='Training Loss', color='blue', linestyle='-', marker='o')
    axes[1].plot(validation_loss, label='Validation Loss', color='green', linestyle='-', marker='o')
    axes[1].set_title('Training and Validation Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()

    plt.tight_layout()

    plt.show()

def save_history(history, filename):
    """Save the history object to a file."""
    with open(filename, 'wb') as file:
        pickle.dump(history.history, file)
    print(f"History object saved successfully in {filename}")
    
def load_history(filename):
    """Load the history object from a file."""
    with open(filename, 'rb') as file:
        history = pickle.load(file)
    print(f"History object loaded successfully from {filename}")
    return history

def plot_confusion_matrices(model, train_generator, validation_generator, classes):
    """Plot confusion matrices for training and validation data."""
    y_pred_train = model.predict(train_generator)
    y_pred_validation = model.predict(validation_generator)

    y_pred_train_classes = np.argmax(y_pred_train, axis=1)
    y_pred_validation_classes = np.argmax(y_pred_validation, axis=1)

    y_true_train = train_generator.classes
    y_true_validation = validation_generator.classes

    cm_train = confusion_matrix(y_true_train, y_pred_train_classes)
    cm_validation = confusion_matrix(y_true_validation, y_pred_validation_classes)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues', xticklabels=classes.values(), yticklabels=classes.values())
    plt.title('Confusion Matrix - Training Data')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    plt.subplot(1, 2, 2)
    sns.heatmap(cm_validation, annot=True, fmt='d', cmap='Blues', xticklabels=classes.values(), yticklabels=classes.values())
    plt.title('Confusion Matrix - Validation Data')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    plt.tight_layout()
    plt.show()

def calculate_and_print_metrics(model, validation_generator):
    """Calculate and print accuracy, precision, recall, and F1-score."""
    y_pred_validation = model.predict(validation_generator)
    y_pred_validation_classes = np.argmax(y_pred_validation, axis=1)
    y_true_validation = validation_generator.classes

    accuracy = np.mean(y_pred_validation_classes == y_true_validation)
    precision = precision_score(y_true_validation, y_pred_validation_classes, average='weighted')
    recall = recall_score(y_true_validation, y_pred_validation_classes, average='weighted')
    f1 = f1_score(y_true_validation, y_pred_validation_classes, average='weighted')

    print(f'Accuracy: ', accuracy)
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1-score: {f1:.4f}')

def save_model(model, filename):
    """Save the model to a file and print the file path."""
    model.save(filename)
    if os.path.exists(filename):
        print(f"Model saved successfully in {filename}")
    else:
        print("Error in saving the model")

    full_path = os.path.abspath(filename)
    print(f"Model saved at: {full_path}")

plot_history(history)
plot_confusion_matrices(model, train_generator, validation_generator, classes)
calculate_and_print_metrics(model, validation_generator)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 332ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step
# Accuracy:  0.5380710659898477
# Precision: 0.5383
# Recall: 0.5381
# F1-score: 0.5378

# %%
save_model(model, 'one_piece_character_classifier3.h5')

save_history(history, 'history_object3.pkl')
loaded_history = load_history('history_object3.pkl')

#acc = loaded_history['acc']
#loss = loaded_history['loss']
# Out:
# 2024-06-02 23:52:56,078 - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully in one_piece_character_classifier3.h5
# Model saved at: c:\Users\oscar\Github\Desarrollo-de-aplicaciones-avanzadas-de-ciencias-computacionales-TC3002B\Inteligencia Artificial\one_piece_character_classifier3.h5
# History object saved successfully in history_object3.pkl
# History object loaded successfully from history_object3.pkl
