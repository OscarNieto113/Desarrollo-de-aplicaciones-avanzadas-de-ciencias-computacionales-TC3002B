# %%
import os
import shutil
import numpy as np
import pickle
import keras
from sklearn.metrics import precision_score, recall_score, f1_score
import logging
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import os

classes = {
        0: 'Ace',
        1: 'Akainu',
        2: 'Brook',
        3: 'Chopper',
        4: 'Crocodile',
        5: 'Franky',
        6: 'Jinbei',
        7: 'Kurohige',
        8: 'Law',
        9: 'Luffy',
        10: 'Mihawk',
        11: 'Nami',
        12: 'Rayleigh',
        13: 'Robin',
        14: 'Sanji',
        15: 'Shanks',
        16: 'Usopp',
        17: 'Zoro',
    }

def create_directories(base_dir, categories):
    """
    Create directories for training, testing, and validation datasets.

    Parameters:
    - base_dir (str): The base directory where the train, test, and validation directories will be created.
    - categories (list): List of category names (sub-directory names) to create inside each of train, test, and validation directories.
    """
    for subset in ['train', 'test', 'validation']:
        for category in categories:
            dir_path = os.path.join(base_dir, subset, category)
            os.makedirs(dir_path, exist_ok=True)
            logging.info(f'Created directory: {dir_path}')

def copy_images(source_dir, images, dest_dir):
    """
    Copy images from source directory to destination directory.

    Parameters:
    - source_dir (str): The directory containing the source images.
    - images (list): List of image filenames to copy.
    - dest_dir (str): The destination directory where images will be copied.
    """
    for image in images:
        shutil.copy(os.path.join(source_dir, image), os.path.join(dest_dir, image))
        logging.info(f'Copied {image} to {dest_dir}')

def split_dataset(source_dir, base_dir, split_ratios=(0.7, 0.15, 0.15)):
    """
    Split the dataset into training, testing, and validation sets.

    Parameters:
    - source_dir (str): The source directory containing subdirectories of images for each category.
    - base_dir (str): The base directory where the split datasets will be stored.
    - split_ratios (tuple): A tuple containing the ratios for splitting the dataset into train, test, and validation sets.

    Raises:
    - ValueError: If the split ratios do not sum to 1.
    """
    if sum(split_ratios) != 1:
        raise ValueError("Split ratios must sum to 1. Provided ratios sum to {:.2f}".format(sum(split_ratios)))
    
    categories = [d for d in os.listdir(source_dir) if os.path.isdir(os.path.join(source_dir, d))]
    create_directories(base_dir, categories)

    for category in categories:
        category_path = os.path.join(source_dir, category)
        images = os.listdir(category_path)
        np.random.shuffle(images)

        train_split = int(len(images) * split_ratios[0])
        test_split = int(len(images) * split_ratios[1])

        train_images = images[:train_split]
        test_images = images[train_split:train_split + test_split]
        validation_images = images[train_split + test_split:]

        copy_images(category_path, train_images, os.path.join(base_dir, 'train', category))
        copy_images(category_path, test_images, os.path.join(base_dir, 'test', category))
        copy_images(category_path, validation_images, os.path.join(base_dir, 'validation', category))
        
def preprocess_image(image_path):
    img = Image.open(image_path)
    if img.mode == 'P' and 'transparency' in img.info:
        img = img.convert('RGBA')
        img = img.convert('RGB')
    if img.mode == 'RGBA':
        img = img.convert('RGB')
    return img

def setup_and_split_dataset(source_dir='Data', base_dir='Dataset_Split', split_ratios=(0.7, 0.15, 0.15)):
    """
    Set up logging, define directories, and split the dataset.

    Parameters:
    - source_dir (str): The source directory containing subdirectories of images for each category.
    - base_dir (str): The base directory where the split datasets will be stored.
    - split_ratios (tuple): A tuple containing the ratios for splitting the dataset into train, test, and validation sets.
    """
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

    try:
        split_dataset(source_dir, base_dir, split_ratios)
    except ValueError as e:
        logging.error(e)
        
def load_dataset(base_dir, target_size=(150, 150), batch_size=32, augmentation=False):
    """
    Load the dataset into variables using ImageDataGenerator.

    Parameters:
    - base_dir (str): The base directory where the split datasets are stored.
    - target_size (tuple): The dimensions to which all images found will be resized.
    - batch_size (int): Size of the batches of data (default: 32).
    - augmentation (bool): Whether to apply data augmentation to the training dataset (default: False).

    Returns:
    - train_generator (DirectoryIterator): Iterator for training dataset.
    - test_generator (DirectoryIterator): Iterator for testing dataset.
    - validation_generator (DirectoryIterator): Iterator for validation dataset.
    """
    if augmentation:
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=90,
            width_shift_range=0.2,
            height_shift_range=0.2,
            shear_range=0.2,
            zoom_range=0.2,
            horizontal_flip=True)
    else:
        train_datagen = ImageDataGenerator(rescale=1./255)

    test_datagen = ImageDataGenerator(rescale=1./255)
    validation_datagen = ImageDataGenerator(rescale=1./255)

    train_generator = train_datagen.flow_from_directory(
        os.path.join(base_dir, 'train'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    test_generator = test_datagen.flow_from_directory(
        os.path.join(base_dir, 'test'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    validation_generator = validation_datagen.flow_from_directory(
        os.path.join(base_dir, 'validation'),
        target_size=target_size,
        batch_size=32,
        class_mode='categorical')

    return train_generator, test_generator, validation_generator

def display_images(images, labels, classes):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        image = images[i]
        if image.shape[-1] == 3:
            image = np.clip(image * 255, 0, 255).astype("uint8")
        plt.imshow(image)
        class_name = classes[labels[i].argmax()]
        plt.title(f"Label: {class_name}")
        plt.axis("off")
    plt.show()

if __name__ == "__main__":
    #setup_and_split_dataset()
    
    base_dir = 'Dataset_Split'
    train_generator, test_generator, validation_generator = load_dataset(base_dir, augmentation=True)

    images, labels = next(train_generator)
    display_images(images, labels, classes)
# Out:
# Found 8204 images belonging to 18 classes.
# Found 1751 images belonging to 18 classes.
# Found 1782 images belonging to 18 classes.

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
import tensorflow.keras.layers as tfl
from tensorflow.keras.models import Model

HEIGHT = 150
WIDTH = 150
CHANNELS = 3

base_model = ResNet50(weights='imagenet',
                      include_top=False,
                      input_shape=(HEIGHT, WIDTH, CHANNELS))

# Congela las capas del modelo base
for layer in base_model.layers:
    layer.trainable = False

# Añade capas personalizadas
x = base_model.output
x = tfl.Flatten()(x)
x = tfl.Dropout(0.2)(x)
x = tfl.Dense(64, activation='relu')(x)
x = tfl.Dropout(0.2)(x)
x = tfl.Dense(32, activation='relu')(x)
output = tfl.Dense(18, activation='softmax')(x)

# Crea el modelo final
model = Model(inputs=base_model.input, outputs=output)

# Compila el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Muestra el resumen del modelo
model.summary()
# Out:
# Model: "functional_23"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_11      │ (None, 150, 150,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 156, 156,  │          0 │ input_layer_11[0… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 75, 75,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 75, 75,    │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 75, 75,    │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 77, 77,    │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 38, 38,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 38, 38,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 38, 38,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 38, 38,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 38, 38,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 38, 38,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 38, 38,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 38, 38,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 38, 38,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 38, 38,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 38, 38,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 38, 38,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 38, 38,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 38, 38,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 38, 38,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 38, 38,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 38, 38,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 38, 38,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 38, 38,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 38, 38,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 38, 38,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 38, 38,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 38, 38,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 38, 38,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 38, 38,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 38, 38,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 38, 38,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 38, 38,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 38, 38,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 38, 38,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 38, 38,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 38, 38,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 38, 38,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 19, 19,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 19, 19,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 19, 19,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 19, 19,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 19, 19,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 19, 19,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 19, 19,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 19, 19,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 19, 19,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 19, 19,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 19, 19,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 19, 19,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 19, 19,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 19, 19,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 19, 19,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 19, 19,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 19, 19,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 19, 19,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 19, 19,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 19, 19,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 19, 19,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 19, 19,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 19, 19,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 19, 19,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 19, 19,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 19, 19,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 19, 19,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 19, 19,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 19, 19,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 19, 19,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 19, 19,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 19, 19,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 19, 19,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 19, 19,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 19, 19,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 19, 19,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 19, 19,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 19, 19,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 19, 19,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 19, 19,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 19, 19,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 19, 19,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 10, 10,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 10, 10,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 10, 10,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 10, 10,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 10, 10,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 10, 10,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 10, 10,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 10, 10,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 10, 10,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 10, 10,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 10, 10,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 10, 10,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 10, 10,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 10, 10,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 10, 10,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 10, 10,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 10, 10,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 10, 10,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 10, 10,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 10, 10,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 10, 10,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 10, 10,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 10, 10,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 10, 10,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 10, 10,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 10, 10,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 10, 10,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 10, 10,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 10, 10,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 10, 10,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 10, 10,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 10, 10,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 10, 10,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 10, 10,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 10, 10,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 10, 10,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 10, 10,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 10, 10,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 10, 10,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 10, 10,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 10, 10,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 10, 10,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 10, 10,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 10, 10,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 10, 10,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 10, 10,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 10, 10,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 10, 10,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 10, 10,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 10, 10,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 10, 10,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 10, 10,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 10, 10,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 10, 10,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 10, 10,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 10, 10,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 10, 10,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 10, 10,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 10, 10,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 10, 10,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 10, 10,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 10, 10,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 5, 5, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 5, 5, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 5, 5, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 5, 5, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 5, 5, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 5, 5, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 5, 5,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 5, 5,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 5, 5,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 5, 5,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 5, 5,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 5, 5,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 5, 5, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 5, 5, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 5, 5, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 5, 5, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 5, 5, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 5, 5, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 5, 5,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 5, 5,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 5, 5,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 5, 5,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 5, 5, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 5, 5, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 5, 5, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 5, 5, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 5, 5, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 5, 5, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 5, 5,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 5, 5,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 5, 5,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 5, 5,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_11          │ (None, 51200)     │          0 │ conv5_block3_out… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 51200)     │          0 │ flatten_11[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 64)        │  3,276,864 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 64)        │          0 │ dense_33[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 32)        │      2,080 │ dropout_23[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_35 (Dense)    │ (None, 18)        │        594 │ dense_34[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,867,250 (102.49 MB)
#  Trainable params: 3,279,538 (12.51 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
history = model.fit(train_generator, epochs=200, validation_data=validation_generator)
# Out:
# Epoch 1/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 161s 603ms/step - accuracy: 0.0560 - loss: 3.0057 - val_accuracy: 0.0561 - val_loss: 2.8899
# Epoch 2/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 598ms/step - accuracy: 0.0573 - loss: 2.8906 - val_accuracy: 0.0561 - val_loss: 2.8900
# Epoch 3/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.0594 - loss: 2.8852 - val_accuracy: 0.0718 - val_loss: 2.8639
# Epoch 4/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.0629 - loss: 2.8657 - val_accuracy: 0.0668 - val_loss: 2.8533
# Epoch 5/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.0669 - loss: 2.8558 - val_accuracy: 0.0696 - val_loss: 2.8737
# Epoch 6/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.0746 - loss: 2.8586 - val_accuracy: 0.0673 - val_loss: 2.8781
# Epoch 7/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.0797 - loss: 2.8529 - val_accuracy: 0.0915 - val_loss: 2.8297
# Epoch 8/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.0758 - loss: 2.8408 - val_accuracy: 0.1004 - val_loss: 2.8074
# Epoch 9/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 596ms/step - accuracy: 0.0929 - loss: 2.8371 - val_accuracy: 0.1044 - val_loss: 2.8063
# Epoch 10/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.0906 - loss: 2.8342 - val_accuracy: 0.0971 - val_loss: 2.8094
# Epoch 11/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.0970 - loss: 2.8282 - val_accuracy: 0.1167 - val_loss: 2.7967
# Epoch 12/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 594ms/step - accuracy: 0.0914 - loss: 2.8312 - val_accuracy: 0.0982 - val_loss: 2.8096
# Epoch 13/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.0917 - loss: 2.8307 - val_accuracy: 0.1105 - val_loss: 2.7897
# Epoch 14/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.0954 - loss: 2.8251 - val_accuracy: 0.0999 - val_loss: 2.7992
# Epoch 15/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.0964 - loss: 2.8230 - val_accuracy: 0.1122 - val_loss: 2.7812
# Epoch 16/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.0985 - loss: 2.8147 - val_accuracy: 0.1139 - val_loss: 2.7782
# Epoch 17/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.0932 - loss: 2.8253 - val_accuracy: 0.1055 - val_loss: 2.8004
# Epoch 18/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.0983 - loss: 2.8190 - val_accuracy: 0.1049 - val_loss: 2.7885
# Epoch 19/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.0994 - loss: 2.8137 - val_accuracy: 0.1150 - val_loss: 2.7781
# Epoch 20/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.0939 - loss: 2.8168 - val_accuracy: 0.1010 - val_loss: 2.8012
# Epoch 21/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.0869 - loss: 2.8213 - val_accuracy: 0.1223 - val_loss: 2.7735
# Epoch 22/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.0984 - loss: 2.8109 - val_accuracy: 0.1201 - val_loss: 2.7700
# Epoch 23/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1038 - loss: 2.8121 - val_accuracy: 0.0875 - val_loss: 2.8218
# Epoch 24/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1030 - loss: 2.8117 - val_accuracy: 0.1094 - val_loss: 2.7873
# Epoch 25/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.0974 - loss: 2.8126 - val_accuracy: 0.1089 - val_loss: 2.7760
# Epoch 26/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.0962 - loss: 2.8218 - val_accuracy: 0.1251 - val_loss: 2.7706
# Epoch 27/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.0951 - loss: 2.8177 - val_accuracy: 0.1251 - val_loss: 2.7701
# Epoch 28/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 596ms/step - accuracy: 0.0996 - loss: 2.8146 - val_accuracy: 0.1291 - val_loss: 2.7648
# Epoch 29/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.0950 - loss: 2.8046 - val_accuracy: 0.1207 - val_loss: 2.7674
# Epoch 30/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1005 - loss: 2.8077 - val_accuracy: 0.1274 - val_loss: 2.7625
# Epoch 31/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1050 - loss: 2.8028 - val_accuracy: 0.1240 - val_loss: 2.7619
# Epoch 32/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1045 - loss: 2.8047 - val_accuracy: 0.1027 - val_loss: 2.7950
# Epoch 33/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1078 - loss: 2.8074 - val_accuracy: 0.1150 - val_loss: 2.7713
# Epoch 34/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 156s 603ms/step - accuracy: 0.1011 - loss: 2.8125 - val_accuracy: 0.1251 - val_loss: 2.7622
# Epoch 35/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 156s 599ms/step - accuracy: 0.1067 - loss: 2.8067 - val_accuracy: 0.1268 - val_loss: 2.7620
# Epoch 36/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 592ms/step - accuracy: 0.1035 - loss: 2.8077 - val_accuracy: 0.0842 - val_loss: 2.8152
# Epoch 37/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1003 - loss: 2.8132 - val_accuracy: 0.1162 - val_loss: 2.7649
# Epoch 38/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1063 - loss: 2.8085 - val_accuracy: 0.1207 - val_loss: 2.7678
# Epoch 39/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1028 - loss: 2.8150 - val_accuracy: 0.1279 - val_loss: 2.7568
# Epoch 40/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1072 - loss: 2.8062 - val_accuracy: 0.1341 - val_loss: 2.7597
# Epoch 41/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.0996 - loss: 2.8023 - val_accuracy: 0.1330 - val_loss: 2.7584
# Epoch 42/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1021 - loss: 2.8110 - val_accuracy: 0.1324 - val_loss: 2.7526
# Epoch 43/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1023 - loss: 2.8088 - val_accuracy: 0.1279 - val_loss: 2.7559
# Epoch 44/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1012 - loss: 2.7998 - val_accuracy: 0.1240 - val_loss: 2.7574
# Epoch 45/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.0993 - loss: 2.8004 - val_accuracy: 0.1240 - val_loss: 2.7582
# Epoch 46/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1013 - loss: 2.8019 - val_accuracy: 0.1279 - val_loss: 2.7574
# Epoch 47/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 592ms/step - accuracy: 0.1068 - loss: 2.8013 - val_accuracy: 0.1195 - val_loss: 2.7661
# Epoch 48/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1048 - loss: 2.8077 - val_accuracy: 0.1251 - val_loss: 2.7593
# Epoch 49/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1038 - loss: 2.8050 - val_accuracy: 0.1369 - val_loss: 2.7521
# Epoch 50/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1094 - loss: 2.7973 - val_accuracy: 0.1134 - val_loss: 2.7604
# Epoch 51/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1057 - loss: 2.8087 - val_accuracy: 0.1324 - val_loss: 2.7469
# Epoch 52/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1066 - loss: 2.8021 - val_accuracy: 0.1184 - val_loss: 2.7538
# Epoch 53/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 591ms/step - accuracy: 0.0967 - loss: 2.8008 - val_accuracy: 0.1285 - val_loss: 2.7497
# Epoch 54/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1058 - loss: 2.7950 - val_accuracy: 0.1257 - val_loss: 2.7523
# Epoch 55/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1040 - loss: 2.8070 - val_accuracy: 0.1246 - val_loss: 2.7465
# Epoch 56/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1071 - loss: 2.7959 - val_accuracy: 0.1336 - val_loss: 2.7453
# Epoch 57/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1086 - loss: 2.7836 - val_accuracy: 0.1313 - val_loss: 2.7472
# Epoch 58/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 596ms/step - accuracy: 0.1005 - loss: 2.8044 - val_accuracy: 0.1150 - val_loss: 2.7547
# Epoch 59/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1048 - loss: 2.8046 - val_accuracy: 0.1364 - val_loss: 2.7459
# Epoch 60/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1051 - loss: 2.7989 - val_accuracy: 0.1263 - val_loss: 2.7539
# Epoch 61/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1078 - loss: 2.7991 - val_accuracy: 0.1291 - val_loss: 2.7441
# Epoch 62/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1110 - loss: 2.7957 - val_accuracy: 0.1369 - val_loss: 2.7434
# Epoch 63/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1058 - loss: 2.7962 - val_accuracy: 0.1330 - val_loss: 2.7445
# Epoch 64/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1164 - loss: 2.7924 - val_accuracy: 0.1207 - val_loss: 2.7667
# Epoch 65/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1021 - loss: 2.7968 - val_accuracy: 0.1330 - val_loss: 2.7504
# Epoch 66/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1153 - loss: 2.7936 - val_accuracy: 0.1302 - val_loss: 2.7536
# Epoch 67/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1097 - loss: 2.7988 - val_accuracy: 0.1375 - val_loss: 2.7433
# Epoch 68/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1118 - loss: 2.7872 - val_accuracy: 0.1352 - val_loss: 2.7445
# Epoch 69/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1068 - loss: 2.7958 - val_accuracy: 0.1380 - val_loss: 2.7434
# Epoch 70/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 156s 599ms/step - accuracy: 0.1178 - loss: 2.7915 - val_accuracy: 0.1291 - val_loss: 2.7527
# Epoch 71/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 156s 602ms/step - accuracy: 0.1050 - loss: 2.8001 - val_accuracy: 0.1352 - val_loss: 2.7447
# Epoch 72/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1147 - loss: 2.7847 - val_accuracy: 0.1341 - val_loss: 2.7468
# Epoch 73/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1137 - loss: 2.7905 - val_accuracy: 0.1184 - val_loss: 2.7733
# Epoch 74/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1077 - loss: 2.7988 - val_accuracy: 0.1291 - val_loss: 2.7478
# Epoch 75/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1067 - loss: 2.7885 - val_accuracy: 0.1308 - val_loss: 2.7496
# Epoch 76/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1152 - loss: 2.7901 - val_accuracy: 0.1279 - val_loss: 2.7528
# Epoch 77/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1132 - loss: 2.7896 - val_accuracy: 0.1285 - val_loss: 2.7538
# Epoch 78/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1033 - loss: 2.8017 - val_accuracy: 0.1128 - val_loss: 2.7783
# Epoch 79/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 593ms/step - accuracy: 0.1093 - loss: 2.7998 - val_accuracy: 0.1336 - val_loss: 2.7460
# Epoch 80/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1069 - loss: 2.7964 - val_accuracy: 0.1274 - val_loss: 2.7554
# Epoch 81/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1100 - loss: 2.7897 - val_accuracy: 0.1263 - val_loss: 2.7490
# Epoch 82/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 157s 606ms/step - accuracy: 0.1106 - loss: 2.7905 - val_accuracy: 0.1375 - val_loss: 2.7453
# Epoch 83/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 156s 600ms/step - accuracy: 0.1035 - loss: 2.8031 - val_accuracy: 0.1380 - val_loss: 2.7435
# Epoch 84/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1154 - loss: 2.7897 - val_accuracy: 0.1369 - val_loss: 2.7453
# Epoch 85/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1144 - loss: 2.7858 - val_accuracy: 0.1319 - val_loss: 2.7442
# Epoch 86/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1064 - loss: 2.7919 - val_accuracy: 0.1246 - val_loss: 2.7583
# Epoch 87/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1097 - loss: 2.7950 - val_accuracy: 0.1313 - val_loss: 2.7518
# Epoch 88/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1052 - loss: 2.7994 - val_accuracy: 0.1392 - val_loss: 2.7408
# Epoch 89/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1146 - loss: 2.7926 - val_accuracy: 0.1330 - val_loss: 2.7438
# Epoch 90/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.0989 - loss: 2.8036 - val_accuracy: 0.1319 - val_loss: 2.7425
# Epoch 91/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1074 - loss: 2.7919 - val_accuracy: 0.1319 - val_loss: 2.7603
# Epoch 92/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1054 - loss: 2.7947 - val_accuracy: 0.1235 - val_loss: 2.7606
# Epoch 93/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1042 - loss: 2.7957 - val_accuracy: 0.1380 - val_loss: 2.7439
# Epoch 94/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1129 - loss: 2.7990 - val_accuracy: 0.1195 - val_loss: 2.7620
# Epoch 95/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1114 - loss: 2.7922 - val_accuracy: 0.1246 - val_loss: 2.7557
# Epoch 96/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1091 - loss: 2.7948 - val_accuracy: 0.1291 - val_loss: 2.7411
# Epoch 97/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1133 - loss: 2.7953 - val_accuracy: 0.1195 - val_loss: 2.7680
# Epoch 98/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1133 - loss: 2.7899 - val_accuracy: 0.1364 - val_loss: 2.7396
# Epoch 99/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 156s 599ms/step - accuracy: 0.1116 - loss: 2.7926 - val_accuracy: 0.1308 - val_loss: 2.7448
# Epoch 100/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1089 - loss: 2.7907 - val_accuracy: 0.1364 - val_loss: 2.7429
# Epoch 101/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1031 - loss: 2.7986 - val_accuracy: 0.1302 - val_loss: 2.7406
# Epoch 102/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1073 - loss: 2.7975 - val_accuracy: 0.1178 - val_loss: 2.7709
# Epoch 103/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1137 - loss: 2.7945 - val_accuracy: 0.1369 - val_loss: 2.7403
# Epoch 104/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1099 - loss: 2.7938 - val_accuracy: 0.1257 - val_loss: 2.7456
# Epoch 105/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1156 - loss: 2.7809 - val_accuracy: 0.1341 - val_loss: 2.7435
# Epoch 106/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1164 - loss: 2.7916 - val_accuracy: 0.1246 - val_loss: 2.7469
# Epoch 107/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1084 - loss: 2.8014 - val_accuracy: 0.1313 - val_loss: 2.7441
# Epoch 108/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1087 - loss: 2.7884 - val_accuracy: 0.1403 - val_loss: 2.7427
# Epoch 109/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1065 - loss: 2.8003 - val_accuracy: 0.1268 - val_loss: 2.7601
# Epoch 110/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1009 - loss: 2.7983 - val_accuracy: 0.1375 - val_loss: 2.7470
# Epoch 111/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1047 - loss: 2.8005 - val_accuracy: 0.1190 - val_loss: 2.7693
# Epoch 112/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1075 - loss: 2.8034 - val_accuracy: 0.1319 - val_loss: 2.7336
# Epoch 113/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1095 - loss: 2.7938 - val_accuracy: 0.1274 - val_loss: 2.7479
# Epoch 114/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1118 - loss: 2.7930 - val_accuracy: 0.1246 - val_loss: 2.7483
# Epoch 115/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1079 - loss: 2.7970 - val_accuracy: 0.1150 - val_loss: 2.7765
# Epoch 116/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1008 - loss: 2.8070 - val_accuracy: 0.1089 - val_loss: 2.7759
# Epoch 117/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 156s 600ms/step - accuracy: 0.1172 - loss: 2.7902 - val_accuracy: 0.1240 - val_loss: 2.7584
# Epoch 118/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1101 - loss: 2.7981 - val_accuracy: 0.1313 - val_loss: 2.7508
# Epoch 119/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1147 - loss: 2.7752 - val_accuracy: 0.1195 - val_loss: 2.7632
# Epoch 120/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1065 - loss: 2.7902 - val_accuracy: 0.1313 - val_loss: 2.7412
# Epoch 121/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1114 - loss: 2.7874 - val_accuracy: 0.1352 - val_loss: 2.7402
# Epoch 122/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1125 - loss: 2.7983 - val_accuracy: 0.1330 - val_loss: 2.7424
# Epoch 123/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1114 - loss: 2.7905 - val_accuracy: 0.1347 - val_loss: 2.7447
# Epoch 124/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1128 - loss: 2.7857 - val_accuracy: 0.1347 - val_loss: 2.7416
# Epoch 125/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1110 - loss: 2.7941 - val_accuracy: 0.1386 - val_loss: 2.7408
# Epoch 126/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1178 - loss: 2.7839 - val_accuracy: 0.1201 - val_loss: 2.7597
# Epoch 127/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1017 - loss: 2.7985 - val_accuracy: 0.1279 - val_loss: 2.7457
# Epoch 128/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1090 - loss: 2.7956 - val_accuracy: 0.1313 - val_loss: 2.7419
# Epoch 129/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1062 - loss: 2.7930 - val_accuracy: 0.1302 - val_loss: 2.7463
# Epoch 130/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 594ms/step - accuracy: 0.1102 - loss: 2.7914 - val_accuracy: 0.1375 - val_loss: 2.7394
# Epoch 131/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 594ms/step - accuracy: 0.1040 - loss: 2.8004 - val_accuracy: 0.1352 - val_loss: 2.7423
# Epoch 132/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1073 - loss: 2.7969 - val_accuracy: 0.1285 - val_loss: 2.7412
# Epoch 133/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1000 - loss: 2.7984 - val_accuracy: 0.1352 - val_loss: 2.7456
# Epoch 134/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 151s 583ms/step - accuracy: 0.1062 - loss: 2.7858 - val_accuracy: 0.1263 - val_loss: 2.7523
# Epoch 135/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1002 - loss: 2.7985 - val_accuracy: 0.1251 - val_loss: 2.7517
# Epoch 136/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1093 - loss: 2.7905 - val_accuracy: 0.1308 - val_loss: 2.7557
# Epoch 137/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1183 - loss: 2.7774 - val_accuracy: 0.1308 - val_loss: 2.7467
# Epoch 138/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 594ms/step - accuracy: 0.1115 - loss: 2.7888 - val_accuracy: 0.1324 - val_loss: 2.7459
# Epoch 139/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1128 - loss: 2.7935 - val_accuracy: 0.1358 - val_loss: 2.7483
# Epoch 140/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1076 - loss: 2.7947 - val_accuracy: 0.1263 - val_loss: 2.7539
# Epoch 141/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1081 - loss: 2.7951 - val_accuracy: 0.1279 - val_loss: 2.7464
# Epoch 142/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1022 - loss: 2.7985 - val_accuracy: 0.1330 - val_loss: 2.7444
# Epoch 143/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1094 - loss: 2.7978 - val_accuracy: 0.1347 - val_loss: 2.7376
# Epoch 144/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1191 - loss: 2.7797 - val_accuracy: 0.1100 - val_loss: 2.7818
# Epoch 145/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1160 - loss: 2.7850 - val_accuracy: 0.1330 - val_loss: 2.7443
# Epoch 146/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1083 - loss: 2.7896 - val_accuracy: 0.1375 - val_loss: 2.7374
# Epoch 147/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1096 - loss: 2.7884 - val_accuracy: 0.1263 - val_loss: 2.7556
# Epoch 148/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1081 - loss: 2.7956 - val_accuracy: 0.1184 - val_loss: 2.7640
# Epoch 149/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1049 - loss: 2.7882 - val_accuracy: 0.1380 - val_loss: 2.7384
# Epoch 150/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1082 - loss: 2.7933 - val_accuracy: 0.1308 - val_loss: 2.7500
# Epoch 151/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 598ms/step - accuracy: 0.1103 - loss: 2.7935 - val_accuracy: 0.1195 - val_loss: 2.7635
# Epoch 152/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1051 - loss: 2.7874 - val_accuracy: 0.1392 - val_loss: 2.7364
# Epoch 153/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 598ms/step - accuracy: 0.1049 - loss: 2.7946 - val_accuracy: 0.1352 - val_loss: 2.7353
# Epoch 154/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1067 - loss: 2.7878 - val_accuracy: 0.1313 - val_loss: 2.7471
# Epoch 155/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1070 - loss: 2.7925 - val_accuracy: 0.1364 - val_loss: 2.7353
# Epoch 156/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1090 - loss: 2.7895 - val_accuracy: 0.1403 - val_loss: 2.7350
# Epoch 157/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 599ms/step - accuracy: 0.1094 - loss: 2.7800 - val_accuracy: 0.1218 - val_loss: 2.7457
# Epoch 158/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1103 - loss: 2.7814 - val_accuracy: 0.1263 - val_loss: 2.7399
# Epoch 159/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1100 - loss: 2.7771 - val_accuracy: 0.1178 - val_loss: 2.7381
# Epoch 160/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 594ms/step - accuracy: 0.1090 - loss: 2.7904 - val_accuracy: 0.1235 - val_loss: 2.7448
# Epoch 161/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1056 - loss: 2.7772 - val_accuracy: 0.1251 - val_loss: 2.7394
# Epoch 162/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1078 - loss: 2.7763 - val_accuracy: 0.1246 - val_loss: 2.7413
# Epoch 163/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1168 - loss: 2.7768 - val_accuracy: 0.1403 - val_loss: 2.7233
# Epoch 164/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1110 - loss: 2.7703 - val_accuracy: 0.1117 - val_loss: 2.7671
# Epoch 165/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1051 - loss: 2.7797 - val_accuracy: 0.1240 - val_loss: 2.7331
# Epoch 166/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1023 - loss: 2.7818 - val_accuracy: 0.1044 - val_loss: 2.7674
# Epoch 167/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1109 - loss: 2.7688 - val_accuracy: 0.1162 - val_loss: 2.7589
# Epoch 168/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1103 - loss: 2.7720 - val_accuracy: 0.1218 - val_loss: 2.7283
# Epoch 169/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1056 - loss: 2.7667 - val_accuracy: 0.1094 - val_loss: 2.7575
# Epoch 170/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 598ms/step - accuracy: 0.1078 - loss: 2.7702 - val_accuracy: 0.1094 - val_loss: 2.7684
# Epoch 171/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 598ms/step - accuracy: 0.1040 - loss: 2.7720 - val_accuracy: 0.1369 - val_loss: 2.7137
# Epoch 172/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1036 - loss: 2.7701 - val_accuracy: 0.1066 - val_loss: 2.7478
# Epoch 173/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1119 - loss: 2.7688 - val_accuracy: 0.1268 - val_loss: 2.7252
# Epoch 174/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1197 - loss: 2.7612 - val_accuracy: 0.1190 - val_loss: 2.7284
# Epoch 175/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1074 - loss: 2.7771 - val_accuracy: 0.1117 - val_loss: 2.7440
# Epoch 176/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 154s 595ms/step - accuracy: 0.1017 - loss: 2.7733 - val_accuracy: 0.1414 - val_loss: 2.7056
# Epoch 177/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1165 - loss: 2.7671 - val_accuracy: 0.1218 - val_loss: 2.7172
# Epoch 178/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1074 - loss: 2.7797 - val_accuracy: 0.1089 - val_loss: 2.7651
# Epoch 179/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1012 - loss: 2.7787 - val_accuracy: 0.1308 - val_loss: 2.7154
# Epoch 180/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1100 - loss: 2.7592 - val_accuracy: 0.1184 - val_loss: 2.7288
# Epoch 181/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 594ms/step - accuracy: 0.1092 - loss: 2.7754 - val_accuracy: 0.1100 - val_loss: 2.7651
# Epoch 182/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1110 - loss: 2.7602 - val_accuracy: 0.1134 - val_loss: 2.7484
# Epoch 183/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1130 - loss: 2.7509 - val_accuracy: 0.1128 - val_loss: 2.7425
# Epoch 184/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1103 - loss: 2.7655 - val_accuracy: 0.1139 - val_loss: 2.7343
# Epoch 185/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1052 - loss: 2.7712 - val_accuracy: 0.1279 - val_loss: 2.7114
# Epoch 186/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1126 - loss: 2.7643 - val_accuracy: 0.1235 - val_loss: 2.7300
# Epoch 187/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1164 - loss: 2.7658 - val_accuracy: 0.1139 - val_loss: 2.7355
# Epoch 188/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1075 - loss: 2.7560 - val_accuracy: 0.1201 - val_loss: 2.7285
# Epoch 189/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1148 - loss: 2.7616 - val_accuracy: 0.1190 - val_loss: 2.7213
# Epoch 190/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1122 - loss: 2.7575 - val_accuracy: 0.1038 - val_loss: 2.7850
# Epoch 191/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1091 - loss: 2.7627 - val_accuracy: 0.1156 - val_loss: 2.7348
# Epoch 192/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 597ms/step - accuracy: 0.1102 - loss: 2.7562 - val_accuracy: 0.1369 - val_loss: 2.7065
# Epoch 193/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1092 - loss: 2.7616 - val_accuracy: 0.1319 - val_loss: 2.7111
# Epoch 194/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1064 - loss: 2.7589 - val_accuracy: 0.1223 - val_loss: 2.7142
# Epoch 195/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1175 - loss: 2.7535 - val_accuracy: 0.1134 - val_loss: 2.7313
# Epoch 196/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 599ms/step - accuracy: 0.1185 - loss: 2.7600 - val_accuracy: 0.1229 - val_loss: 2.7242
# Epoch 197/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1082 - loss: 2.7629 - val_accuracy: 0.1049 - val_loss: 2.7681
# Epoch 198/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 595ms/step - accuracy: 0.1080 - loss: 2.7656 - val_accuracy: 0.1122 - val_loss: 2.7352
# Epoch 199/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 598ms/step - accuracy: 0.1148 - loss: 2.7559 - val_accuracy: 0.1223 - val_loss: 2.7164
# Epoch 200/200
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 155s 596ms/step - accuracy: 0.1138 - loss: 2.7542 - val_accuracy: 0.1246 - val_loss: 2.7152

# %%
def plot_history(history):
    training_accuracy = history.history['accuracy']
    validation_accuracy = history.history['val_accuracy']
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].plot(training_accuracy, label='Training Accuracy', color='blue', linestyle='-', marker='o')
    axes[0].plot(validation_accuracy, label='Validation Accuracy', color='green', linestyle='-', marker='o')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()

    axes[1].plot(training_loss, label='Training Loss', color='blue', linestyle='-', marker='o')
    axes[1].plot(validation_loss, label='Validation Loss', color='green', linestyle='-', marker='o')
    axes[1].set_title('Training and Validation Loss')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Loss')
    axes[1].legend()

    plt.tight_layout()

    plt.show()

def save_history(history, filename):
    """Save the history object to a file."""
    with open(filename, 'wb') as file:
        pickle.dump(history.history, file)
    print(f"History object saved successfully in {filename}")
    
def load_history(filename):
    """Load the history object from a file."""
    with open(filename, 'rb') as file:
        history = pickle.load(file)
    print(f"History object loaded successfully from {filename}")
    return history

def plot_confusion_matrices(model, train_generator, validation_generator, classes):
    """Plot confusion matrices for training and validation data."""
    y_pred_train = model.predict(train_generator)
    y_pred_validation = model.predict(validation_generator)

    y_pred_train_classes = np.argmax(y_pred_train, axis=1)
    y_pred_validation_classes = np.argmax(y_pred_validation, axis=1)

    y_true_train = train_generator.classes
    y_true_validation = validation_generator.classes

    cm_train = confusion_matrix(y_true_train, y_pred_train_classes)
    cm_validation = confusion_matrix(y_true_validation, y_pred_validation_classes)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues', xticklabels=classes.values(), yticklabels=classes.values())
    plt.title('Confusion Matrix - Training Data')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    plt.subplot(1, 2, 2)
    sns.heatmap(cm_validation, annot=True, fmt='d', cmap='Blues', xticklabels=classes.values(), yticklabels=classes.values())
    plt.title('Confusion Matrix - Validation Data')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    plt.tight_layout()
    plt.show()

def calculate_and_print_metrics(model, validation_generator):
    """Calculate and print accuracy, precision, recall, and F1-score."""
    y_pred_validation = model.predict(validation_generator)
    y_pred_validation_classes = np.argmax(y_pred_validation, axis=1)
    y_true_validation = validation_generator.classes

    accuracy = np.mean(y_pred_validation_classes == y_true_validation)
    precision = precision_score(y_true_validation, y_pred_validation_classes, average='weighted')
    recall = recall_score(y_true_validation, y_pred_validation_classes, average='weighted')
    f1 = f1_score(y_true_validation, y_pred_validation_classes, average='weighted')

    print(f'Accuracy: ', accuracy)
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1-score: {f1:.4f}')

def save_model(model, filename):
    """Save the model to a file and print the file path."""
    model.save(filename)
    if os.path.exists(filename):
        print(f"Model saved successfully in {filename}")
    else:
        print("Error in saving the model")

    full_path = os.path.abspath(filename)
    print(f"Model saved at: {full_path}")

plot_history(history)
plot_confusion_matrices(model, train_generator, validation_generator, classes)
calculate_and_print_metrics(model, validation_generator)
# Out:
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 133s 514ms/step
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 25s 453ms/step
#  6/56 ━━━━━━━━━━━━━━━━━━━━ 23s 479ms/step
# c:\Python312\Lib\site-packages\PIL\Image.py:1000: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 25s 447ms/step
# Accuracy:  0.05218855218855219
# Precision: 0.0219
# Recall: 0.0522
# F1-score: 0.0303
# c:\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
save_model(model, 'one_piece_character_classifier2.h5')

save_history(history, 'history_object2.pkl')
loaded_history = load_history('history_object2.pkl')

#acc = loaded_history['acc']
#loss = loaded_history['loss']
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully in one_piece_character_classifier2.h5
# Model saved at: c:\Users\oscar\Github\Desarrollo-de-aplicaciones-avanzadas-de-ciencias-computacionales-TC3002B\Inteligencia Artificial\one_piece_character_classifier2.h5
# History object saved successfully in history_object2.pkl
# History object loaded successfully from history_object2.pkl
